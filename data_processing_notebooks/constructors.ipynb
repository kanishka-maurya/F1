# %% [markdown]
# # **EXPLORATORY DATA ANALYSIS**

# %%
import pandas as pd

# %% [markdown]
# # **CONSTRUCTORS**

# %%
df_cons = pd.read_parquet(r"C:\Users\Asus\Desktop\Formula1\data\bronze\entities\constructors.parquet")
df_cons.head()
# Out:
#   constructor_ref constructor_name nationality
# 0           adams            Adams    American
# 1             afm              AFM      German
# 2             ags              AGS      French
# 3            alfa       Alfa Romeo       Swiss
# 4      alphatauri       AlphaTauri     Italian

# %% [markdown]
# - constructor_ref is **PRIMARY KEY**

# %%
df_cons.shape
# Out:
# (214, 3)

# %%
len(df_cons["constructor_ref"].unique())
# Out:
# 214

# %%
len(df_cons["constructor_name"].unique())
# Out:
# 214

# %%
df_cons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   constructor_ref   214 non-null    object
#  1   constructor_name  214 non-null    object
#  2   nationality       214 non-null    object
# dtypes: object(3)
# memory usage: 5.1+ KB

# %%
df_cons.to_parquet(r"C:\Users\Asus\Desktop\Formula1\data\silver\entities\cleaned_constructors.parquet")
