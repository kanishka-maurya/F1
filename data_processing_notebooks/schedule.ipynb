# %% [markdown]
# # **EXPLORATORY DATA ANALYSIS**

# %%
import pandas as pd

# %% [markdown]
# # **SCHEDULE**

# %%
df_schedule = pd.read_parquet(r"C:\Users\Asus\Desktop\Formula1\data\bronze\schedule\all_seasons_schedule.parquet")
df_schedule.head()
# Out:
#    season  round_number              race_name  circuit_ref   race_date  \
# 0    2010             1     Bahrain Grand Prix      bahrain  2010-03-14
# 1    2010             2  Australian Grand Prix  albert_park  2010-03-28
# 2    2010             3   Malaysian Grand Prix       sepang  2010-04-04
# 3    2010             4     Chinese Grand Prix     shanghai  2010-04-18
# 4    2010             5     Spanish Grand Prix    catalunya  2010-05-09
#
#    race_time    fp1_date    fp2_date    fp3_date  quali_date sprint_date  \
# 0  12:00:00Z  2010-03-12  2010-03-12  2010-03-13  2010-03-13        None
# 1  06:00:00Z  2010-03-26  2010-03-26  2010-03-27  2010-03-27        None
# 2  08:00:00Z  2010-04-02  2010-04-02  2010-04-03  2010-04-03        None
# 3  06:00:00Z  2010-04-16  2010-04-16  2010-04-17  2010-04-17        None
# 4  12:00:00Z  2010-05-07  2010-05-07  2010-05-08  2010-05-08        None
#
#    has_sprint
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False

# %% [markdown]
# - no **PRIMARY KEY**

# %%
df_schedule.shape
# Out:
# (329, 12)

# %%
len(df_schedule["season"].unique())
# Out:
# 16

# %%
df_schedule.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 329 entries, 0 to 328
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   season        329 non-null    int64
#  1   round_number  329 non-null    int64
#  2   race_name     329 non-null    object
#  3   circuit_ref   329 non-null    object
#  4   race_date     329 non-null    object
#  5   race_time     329 non-null    object
#  6   fp1_date      329 non-null    object
#  7   fp2_date      311 non-null    object
#  8   fp3_date      305 non-null    object
#  9   quali_date    329 non-null    object
#  10  sprint_date   24 non-null     object
#  11  has_sprint    329 non-null    bool
# dtypes: bool(1), int64(2), object(9)
# memory usage: 28.7+ KB

# %% [markdown]
# - creating **PRIMARY KEY**
# - combination of season and round_number columns is unique

# %%
df_schedule["schedule_ref"] = df_schedule["season"].astype(str) + "_" + df_schedule["round_number"].astype(str)

# %%
len(df_schedule["schedule_ref"].unique())
# Out:
# 329

# %% [markdown]
# - handling race_time and race_date columns
# - combining both the columns meticulously

# %%
df_schedule['race_datetime'] = pd.to_datetime(
    df_schedule['race_date'].astype(str) + ' ' + df_schedule['race_time'].astype(str),
    utc=True
)

# %%
df_schedule.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 329 entries, 0 to 328
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   season         329 non-null    int64
#  1   round_number   329 non-null    int64
#  2   race_name      329 non-null    object
#  3   circuit_ref    329 non-null    object
#  4   race_date      329 non-null    object
#  5   race_time      329 non-null    object
#  6   fp1_date       329 non-null    object
#  7   fp2_date       311 non-null    object
#  8   fp3_date       305 non-null    object
#  9   quali_date     329 non-null    object
#  10  sprint_date    24 non-null     object
#  11  has_sprint     329 non-null    bool
#  12  schedule_ref   329 non-null    object
#  13  race_datetime  329 non-null    datetime64[ns, UTC]
# dtypes: bool(1), datetime64[ns, UTC](1), int64(2), object(10)
# memory usage: 33.9+ KB

# %% [markdown]
# - handling fp2_date, fp3_date and quali_date columns

# %%
df_schedule[df_schedule["fp2_date"].isna()]
# 299  2024-10-19        True      2024_19 2024-10-20 19:00:00+00:00
# 301  2024-11-02        True      2024_21 2024-11-03 17:00:00+00:00
# 303  2024-11-30        True      2024_23 2024-12-01 16:00:00+00:00
# 306  2025-03-22        True       2025_2 2025-03-23 07:00:00+00:00
# 310  2025-05-03        True       2025_6 2025-05-04 20:00:00+00:00
# 317  2025-07-26        True      2025_13 2025-07-27 13:00:00+00:00
# 323  2025-10-18        True      2025_19 2025-10-19 19:00:00+00:00
# 325  2025-11-08        True      2025_21 2025-11-09 17:00:00+00:00
# 327  2025-11-29        True      2025_23 2025-11-30 16:00:00+00:00

# %%
df_schedule['fp1_date'] = pd.to_datetime(df_schedule['fp1_date'], errors='coerce')
df_schedule['fp2_date'] = pd.to_datetime(df_schedule['fp2_date'], errors='coerce')
df_schedule['fp3_date'] = pd.to_datetime(df_schedule['fp3_date'], errors='coerce')
df_schedule['quali_date'] = pd.to_datetime(df_schedule['quali_date'], errors='coerce')

# %% [markdown]
# - removing sprint_date, race_date and race_time column

# %%
df_schedule.drop(columns=["race_date", "race_time", "sprint_date"], inplace=True)

# %%
df_schedule = df_schedule[["schedule_ref", "season", "round_number", "race_name", "race_datetime", "circuit_ref",
                           "fp1_date", "fp2_date", "fp3_date", "quali_date", "has_sprint"]]

# %%
df_schedule.head()
# Out:
#   schedule_ref  season  round_number              race_name  \
# 0       2010_1    2010             1     Bahrain Grand Prix
# 1       2010_2    2010             2  Australian Grand Prix
# 2       2010_3    2010             3   Malaysian Grand Prix
# 3       2010_4    2010             4     Chinese Grand Prix
# 4       2010_5    2010             5     Spanish Grand Prix
#
#               race_datetime  circuit_ref   fp1_date   fp2_date   fp3_date  \
# 0 2010-03-14 12:00:00+00:00      bahrain 2010-03-12 2010-03-12 2010-03-13
# 1 2010-03-28 06:00:00+00:00  albert_park 2010-03-26 2010-03-26 2010-03-27
# 2 2010-04-04 08:00:00+00:00       sepang 2010-04-02 2010-04-02 2010-04-03
# 3 2010-04-18 06:00:00+00:00     shanghai 2010-04-16 2010-04-16 2010-04-17
# 4 2010-05-09 12:00:00+00:00    catalunya 2010-05-07 2010-05-07 2010-05-08
#
#   quali_date  has_sprint
# 0 2010-03-13       False
# 1 2010-03-27       False
# 2 2010-04-03       False
# 3 2010-04-17       False
# 4 2010-05-08       False

# %%
df_schedule.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 329 entries, 0 to 328
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   schedule_ref   329 non-null    object
#  1   season         329 non-null    int64
#  2   round_number   329 non-null    int64
#  3   race_name      329 non-null    object
#  4   race_datetime  329 non-null    datetime64[ns, UTC]
#  5   circuit_ref    329 non-null    object
#  6   fp1_date       329 non-null    datetime64[ns]
#  7   fp2_date       311 non-null    datetime64[ns]
#  8   fp3_date       305 non-null    datetime64[ns]
#  9   quali_date     329 non-null    datetime64[ns]
#  10  has_sprint     329 non-null    bool
# dtypes: bool(1), datetime64[ns, UTC](1), datetime64[ns](4), int64(2), object(3)
# memory usage: 26.2+ KB

# %%
df_schedule.to_parquet(r"C:\Users\Asus\Desktop\Formula1\data\silver\schedule\cleaned_schedule.parquet")
