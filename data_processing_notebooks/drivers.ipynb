# %%
import pandas as pd
import fastf1
from fastf1.ergast import Ergast

# %%
df = pd.read_parquet(
    r'C:\Users\Asus\Desktop\Formula1\data\bronze\pit_stops\2018_R03_pit_stops.parquet'
)

# %%
df
# Out:
#     season  round_number           race_name circuit_ref   race_date  \
# 0     2018             3  Chinese Grand Prix    shanghai  2018-04-15
# 1     2018             3  Chinese Grand Prix    shanghai  2018-04-15
# 2     2018             3  Chinese Grand Prix    shanghai  2018-04-15
# 3     2018             3  Chinese Grand Prix    shanghai  2018-04-15
# 4     2018             3  Chinese Grand Prix    shanghai  2018-04-15
# 5     2018             3  Chinese Grand Prix    shanghai  2018-04-15
# 6     2018             3  Chinese Grand Prix    shanghai  2018-04-15
# 7     2018             3  Chinese Grand Prix    shanghai  2018-04-15
# 8     2018             3  Chinese Grand Prix    shanghai  2018-04-15
# 9     2018             3  Chinese Grand Prix    shanghai  2018-04-15
# 10    2018             3  Chinese Grand Prix    shanghai  2018-04-15
# 11    2018             3  Chinese Grand Prix    shanghai  2018-04-15
# 12    2018             3  Chinese Grand Prix    shanghai  2018-04-15
# 13    2018             3  Chinese Grand Prix    shanghai  2018-04-15
# 14    2018             3  Chinese Grand Prix    shanghai  2018-04-15
# 15    2018             3  Chinese Grand Prix    shanghai  2018-04-15
# 16    2018             3  Chinese Grand Prix    shanghai  2018-04-15
# 17    2018             3  Chinese Grand Prix    shanghai  2018-04-15
# 18    2018             3  Chinese Grand Prix    shanghai  2018-04-15
# 19    2018             3  Chinese Grand Prix    shanghai  2018-04-15
# 20    2018             3  Chinese Grand Prix    shanghai  2018-04-15
# 21    2018             3  Chinese Grand Prix    shanghai  2018-04-15
# 22    2018             3  Chinese Grand Prix    shanghai  2018-04-15
# 23    2018             3  Chinese Grand Prix    shanghai  2018-04-15
# 24    2018             3  Chinese Grand Prix    shanghai  2018-04-15
# 25    2018             3  Chinese Grand Prix    shanghai  2018-04-15
# 26    2018             3  Chinese Grand Prix    shanghai  2018-04-15
# 27    2018             3  Chinese Grand Prix    shanghai  2018-04-15
# 28    2018             3  Chinese Grand Prix    shanghai  2018-04-15
# 29    2018             3  Chinese Grand Prix    shanghai  2018-04-15
#
#          driver_ref  stop_number  lap_number local_time duration  duration_ms  \
# 0            alonso            1          29   15:02:24   24.110      24110.0
# 1            bottas            1          19   14:45:02   22.097      22097.0
# 2   brendon_hartley            1          10   14:30:52   23.172      23172.0
# 3   brendon_hartley            2          30   15:05:08   24.070      24070.0
# 4          ericsson            1          29   15:03:02   22.785      22785.0
# 5             gasly            1          20   14:47:48   23.950      23950.0
# 6             gasly            2          31   15:07:01   34.650      34650.0
# 7          grosjean            1          16   14:40:41   22.981      22981.0
# 8          grosjean            2          46   15:33:38   23.735      23735.0
# 9          hamilton            1          18   14:43:33   22.464      22464.0
# 10       hulkenberg            1          13   14:35:30   23.654      23654.0
# 11       hulkenberg            2          31   15:06:04   23.297      23297.0
# 12  kevin_magnussen            1          24   14:53:57   22.973      22973.0
# 13          leclerc            1          21   14:49:28   23.392      23392.0
# 14   max_verstappen            1          17   14:41:50   22.715      22715.0
# 15   max_verstappen            2          31   15:05:06   22.596      22596.0
# 16             ocon            1          11   14:32:18   23.281      23281.0
# 17             ocon            2          31   15:06:24   22.637      22637.0
# 18            perez            1          12   14:34:05   22.856      22856.0
# 19            perez            2          32   15:08:44   22.334      22334.0
# 20        raikkonen            1          27   14:58:28   22.913      22913.0
# 21        ricciardo            1          17   14:41:56   23.042      23042.0
# 22        ricciardo            2          31   15:05:15   22.691      22691.0
# 23            sainz            1          12   14:33:53   23.935      23935.0
# 24            sainz            2          31   15:06:18   23.117      23117.0
# 25         sirotkin            1          28   15:01:08   23.716      23716.0
# 26         sirotkin            2          33   15:11:07   22.723      22723.0
# 27           stroll            1          23   14:52:34   22.661      22661.0
# 28        vandoorne            1          22   14:50:55   23.730      23730.0
# 29           vettel            1          20   14:46:38   23.009      23009.0
#
#     total_stops_race  avg_duration_ms_race
# 0                  1               24110.0
# 1                  1               22097.0
# 2                  2               23621.0
# 3                  2               23621.0
# 4                  1               22785.0
# 5                  2               29300.0
# 6                  2               29300.0
# 7                  2               23358.0
# 8                  2               23358.0
# 9                  1               22464.0
# 10                 2               23475.5
# 11                 2               23475.5
# 12                 1               22973.0
# 13                 1               23392.0
# 14                 2               22655.5
# 15                 2               22655.5
# 16                 2               22959.0
# 17                 2               22959.0
# 18                 2               22595.0
# 19                 2               22595.0
# 20                 1               22913.0
# 21                 2               22866.5
# 22                 2               22866.5
# 23                 2               23526.0
# 24                 2               23526.0
# 25                 2               23219.5
# 26                 2               23219.5
# 27                 1               22661.0
# 28                 1               23730.0
# 29                 1               23009.0

# %%
df.to_csv("abcd.csv")

# %%
# Initialize Ergast API client with desired settings
ergast = Ergast(
    result_type='pandas',  # 'pandas'
    auto_cast=True,        # Automatic type conversion
    limit=1000             # Max results per request (default: 30, max: 1000)
)

# %% [markdown]
# # Drivers

# %%
drivers_df = pd.DataFrame()

for season in range(2010, 2026):
    print(f"Season: {season}")

    # Get all drivers from a season
    drivers = ergast.get_driver_info(season=season)

    drivers = drivers[["driverId", "driverNumber", "driverCode", "givenName", "familyName", "dateOfBirth", "driverNationality"]]

    drivers_df = pd.concat([drivers_df, drivers], ignore_index=True)

    print(drivers.columns)
# Out:
# Season: 2010
# Index(['driverId', 'driverNumber', 'driverCode', 'givenName', 'familyName',
#        'dateOfBirth', 'driverNationality'],
#       dtype='object')
# Season: 2011
# Index(['driverId', 'driverNumber', 'driverCode', 'givenName', 'familyName',
#        'dateOfBirth', 'driverNationality'],
#       dtype='object')
# Season: 2012
# Index(['driverId', 'driverNumber', 'driverCode', 'givenName', 'familyName',
#        'dateOfBirth', 'driverNationality'],
#       dtype='object')
# Season: 2013
# Index(['driverId', 'driverNumber', 'driverCode', 'givenName', 'familyName',
#        'dateOfBirth', 'driverNationality'],
#       dtype='object')
# Season: 2014
# Index(['driverId', 'driverNumber', 'driverCode', 'givenName', 'familyName',
#        'dateOfBirth', 'driverNationality'],
#       dtype='object')
# Season: 2015
# Index(['driverId', 'driverNumber', 'driverCode', 'givenName', 'familyName',
#        'dateOfBirth', 'driverNationality'],
#       dtype='object')
# Season: 2016
# Index(['driverId', 'driverNumber', 'driverCode', 'givenName', 'familyName',
#        'dateOfBirth', 'driverNationality'],
#       dtype='object')
# Season: 2017
# Index(['driverId', 'driverNumber', 'driverCode', 'givenName', 'familyName',
#        'dateOfBirth', 'driverNationality'],
#       dtype='object')
# Season: 2018
# Index(['driverId', 'driverNumber', 'driverCode', 'givenName', 'familyName',
#        'dateOfBirth', 'driverNationality'],
#       dtype='object')
# Season: 2019
# Index(['driverId', 'driverNumber', 'driverCode', 'givenName', 'familyName',
#        'dateOfBirth', 'driverNationality'],
#       dtype='object')
# Season: 2020
# Index(['driverId', 'driverNumber', 'driverCode', 'givenName', 'familyName',
#        'dateOfBirth', 'driverNationality'],
#       dtype='object')
# Season: 2021
# Index(['driverId', 'driverNumber', 'driverCode', 'givenName', 'familyName',
#        'dateOfBirth', 'driverNationality'],
#       dtype='object')
# Season: 2022
# Index(['driverId', 'driverNumber', 'driverCode', 'givenName', 'familyName',
#        'dateOfBirth', 'driverNationality'],
#       dtype='object')
# Season: 2023
# Index(['driverId', 'driverNumber', 'driverCode', 'givenName', 'familyName',
#        'dateOfBirth', 'driverNationality'],
#       dtype='object')
# Season: 2024
# Index(['driverId', 'driverNumber', 'driverCode', 'givenName', 'familyName',
#        'dateOfBirth', 'driverNationality'],
#       dtype='object')
# Season: 2025
# Index(['driverId', 'driverNumber', 'driverCode', 'givenName', 'familyName',
#        'dateOfBirth', 'driverNationality'],
#       dtype='object')

# %%
drivers_df.shape
# Out:
# (387, 7)

# %%
drivers_df = drivers_df.drop_duplicates()

# %%
drivers_df.shape
# Out:
# (98, 7)

# %%
drivers_df.info()
# Out:
# <class 'fastf1.ergast.interface.ErgastResultFrame'>
# Index: 98 entries, 0 to 386
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   driverId           98 non-null     object
#  1   driverNumber       63 non-null     float64
#  2   driverCode         84 non-null     object
#  3   givenName          98 non-null     object
#  4   familyName         98 non-null     object
#  5   dateOfBirth        84 non-null     datetime64[ns]
#  6   driverNationality  84 non-null     object
# dtypes: datetime64[ns](1), float64(1), object(5)
# memory usage: 6.1+ KB

# %%
drivers_df.head(10)
# Out:
#       driverId  driverNumber driverCode  givenName   familyName dateOfBirth  \
# 0  alguersuari           NaN        ALG      Jaime  Alguersuari  1990-03-23
# 1       alonso          14.0        ALO   Fernando       Alonso  1981-07-29
# 2  barrichello           NaN        BAR     Rubens  Barrichello  1972-05-23
# 3        buemi           NaN        BUE  Sébastien        Buemi  1988-10-31
# 4       button          22.0        BUT     Jenson       Button  1980-01-19
# 5     chandhok           NaN        CHA      Karun     Chandhok  1984-01-19
# 6        glock           NaN        GLO       Timo        Glock  1982-03-18
# 7     hamilton          44.0        HAM      Lewis     Hamilton  1985-01-07
# 8     heidfeld           NaN        HEI       Nick     Heidfeld  1977-05-10
# 9   hulkenberg          27.0        HUL       Nico   Hülkenberg  1987-08-19
#
#   driverNationality
# 0           Spanish
# 1           Spanish
# 2         Brazilian
# 3             Swiss
# 4           British
# 5            Indian
# 6            German
# 7           British
# 8            German
# 9            German

# %% [markdown]
# # Constructors

# %%
constructors_df = pd.DataFrame()

for season in range(2010, 2026):
    print(f"Season: {season}")

    constructors = ergast.get_constructor_info(season=season)

    constructors = constructors[['constructorId', 'constructorName', 'constructorNationality']]

    constructors_df = pd.concat([constructors_df, constructors], ignore_index=True)

    print(constructors_df.columns)
# Out:
# Season: 2010
# Index(['constructorId', 'constructorName', 'constructorNationality'], dtype='object')
# Season: 2011
# Index(['constructorId', 'constructorName', 'constructorNationality'], dtype='object')
# Season: 2012
# Index(['constructorId', 'constructorName', 'constructorNationality'], dtype='object')
# Season: 2013
# Index(['constructorId', 'constructorName', 'constructorNationality'], dtype='object')
# Season: 2014
# Index(['constructorId', 'constructorName', 'constructorNationality'], dtype='object')
# Season: 2015
# Index(['constructorId', 'constructorName', 'constructorNationality'], dtype='object')
# Season: 2016
# Index(['constructorId', 'constructorName', 'constructorNationality'], dtype='object')
# Season: 2017
# Index(['constructorId', 'constructorName', 'constructorNationality'], dtype='object')
# Season: 2018
# Index(['constructorId', 'constructorName', 'constructorNationality'], dtype='object')
# Season: 2019
# Index(['constructorId', 'constructorName', 'constructorNationality'], dtype='object')
# Season: 2020
# Index(['constructorId', 'constructorName', 'constructorNationality'], dtype='object')
# Season: 2021
# Index(['constructorId', 'constructorName', 'constructorNationality'], dtype='object')
# Season: 2022
# Index(['constructorId', 'constructorName', 'constructorNationality'], dtype='object')
# Season: 2023
# Index(['constructorId', 'constructorName', 'constructorNationality'], dtype='object')
# Season: 2024
# Index(['constructorId', 'constructorName', 'constructorNationality'], dtype='object')
# Season: 2025
# Index(['constructorId', 'constructorName', 'constructorNationality'], dtype='object')

# %%
constructors_df.head()
# Out:
#   constructorId constructorName constructorNationality
# 0       ferrari         Ferrari                Italian
# 1   force_india     Force India                 Indian
# 2           hrt             HRT                Spanish
# 3  lotus_racing           Lotus              Malaysian
# 4       mclaren         McLaren                British

# %%
constructors_df.shape
# Out:
# (169, 3)

# %%
constructors_df = constructors_df.drop_duplicates()

# %%
constructors_df.shape
# Out:
# (23, 3)

# %%
constructors_df
# Out:
#     constructorId constructorName constructorNationality
# 0         ferrari         Ferrari                Italian
# 1     force_india     Force India                 Indian
# 2             hrt             HRT                Spanish
# 3    lotus_racing           Lotus              Malaysian
# 4         mclaren         McLaren                British
# 5        mercedes        Mercedes                 German
# 6        red_bull        Red Bull               Austrian
# 7         renault         Renault                 French
# 8          sauber          Sauber                  Swiss
# 9      toro_rosso      Toro Rosso                Italian
# 10         virgin          Virgin                British
# 11       williams        Williams                British
# 24       caterham        Caterham              Malaysian
# 28       lotus_f1        Lotus F1                British
# 29       marussia        Marussia                Russian
# 61          manor  Manor Marussia                British
# 70           haas    Haas F1 Team               American
# 99           alfa      Alfa Romeo                  Swiss
# 104  racing_point    Racing Point                British
# 110    alphatauri      AlphaTauri                Italian
# 121        alpine  Alpine F1 Team                 French
# 122  aston_martin    Aston Martin                British
# 155            rb      RB F1 Team                Italian

# %%
circuits_df = pd.DataFrame()

for season in range(2010, 2026):
    print(f"Season: {season}")  
    # Get all circuits from a season
    circuits = ergast.get_circuits(season=season)
    print(circuits.columns)

    
    circuits = circuits[['circuitId', 'circuitName', 'lat', 'long', 'locality',
       'country']]

    circuits_df = pd.concat([circuits_df, circuits], ignore_index=True)

    print(circuits_df.columns)
# Out:
# Season: 2010
# Index(['circuitId', 'circuitUrl', 'circuitName', 'lat', 'long', 'locality',
#        'country'],
#       dtype='object')
# Index(['circuitId', 'circuitName', 'lat', 'long', 'locality', 'country'], dtype='object')
# Season: 2011
# Index(['circuitId', 'circuitUrl', 'circuitName', 'lat', 'long', 'locality',
#        'country'],
#       dtype='object')
# Index(['circuitId', 'circuitName', 'lat', 'long', 'locality', 'country'], dtype='object')
# Season: 2012
# Index(['circuitId', 'circuitUrl', 'circuitName', 'lat', 'long', 'locality',
#        'country'],
#       dtype='object')
# Index(['circuitId', 'circuitName', 'lat', 'long', 'locality', 'country'], dtype='object')
# Season: 2013
# Index(['circuitId', 'circuitUrl', 'circuitName', 'lat', 'long', 'locality',
#        'country'],
#       dtype='object')
# Index(['circuitId', 'circuitName', 'lat', 'long', 'locality', 'country'], dtype='object')
# Season: 2014
# Index(['circuitId', 'circuitUrl', 'circuitName', 'lat', 'long', 'locality',
#        'country'],
#       dtype='object')
# Index(['circuitId', 'circuitName', 'lat', 'long', 'locality', 'country'], dtype='object')
# Season: 2015
# Index(['circuitId', 'circuitUrl', 'circuitName', 'lat', 'long', 'locality',
#        'country'],
#       dtype='object')
# Index(['circuitId', 'circuitName', 'lat', 'long', 'locality', 'country'], dtype='object')
# Season: 2016
# Index(['circuitId', 'circuitUrl', 'circuitName', 'lat', 'long', 'locality',
#        'country'],
#       dtype='object')
# Index(['circuitId', 'circuitName', 'lat', 'long', 'locality', 'country'], dtype='object')
# Season: 2017
# Index(['circuitId', 'circuitUrl', 'circuitName', 'lat', 'long', 'locality',
#        'country'],
#       dtype='object')
# Index(['circuitId', 'circuitName', 'lat', 'long', 'locality', 'country'], dtype='object')
# Season: 2018
# Index(['circuitId', 'circuitUrl', 'circuitName', 'lat', 'long', 'locality',
#        'country'],
#       dtype='object')
# Index(['circuitId', 'circuitName', 'lat', 'long', 'locality', 'country'], dtype='object')
# Season: 2019
# Index(['circuitId', 'circuitUrl', 'circuitName', 'lat', 'long', 'locality',
#        'country'],
#       dtype='object')
# Index(['circuitId', 'circuitName', 'lat', 'long', 'locality', 'country'], dtype='object')
# Season: 2020
# Index(['circuitId', 'circuitUrl', 'circuitName', 'lat', 'long', 'locality',
#        'country'],
#       dtype='object')
# Index(['circuitId', 'circuitName', 'lat', 'long', 'locality', 'country'], dtype='object')
# Season: 2021
# Index(['circuitId', 'circuitUrl', 'circuitName', 'lat', 'long', 'locality',
#        'country'],
#       dtype='object')
# Index(['circuitId', 'circuitName', 'lat', 'long', 'locality', 'country'], dtype='object')
# Season: 2022
# Index(['circuitId', 'circuitUrl', 'circuitName', 'lat', 'long', 'locality',
#        'country'],
#       dtype='object')
# Index(['circuitId', 'circuitName', 'lat', 'long', 'locality', 'country'], dtype='object')
# Season: 2023
# Index(['circuitId', 'circuitUrl', 'circuitName', 'lat', 'long', 'locality',
#        'country'],
#       dtype='object')
# Index(['circuitId', 'circuitName', 'lat', 'long', 'locality', 'country'], dtype='object')
# Season: 2024
# Index(['circuitId', 'circuitUrl', 'circuitName', 'lat', 'long', 'locality',
#        'country'],
#       dtype='object')
# Index(['circuitId', 'circuitName', 'lat', 'long', 'locality', 'country'], dtype='object')
# Season: 2025
# Index(['circuitId', 'circuitUrl', 'circuitName', 'lat', 'long', 'locality',
#        'country'],
#       dtype='object')
# Index(['circuitId', 'circuitName', 'lat', 'long', 'locality', 'country'], dtype='object')

# %%
circuits_df = circuits_df.drop_duplicates()

# %%
circuits_df.shape
# Out:
# (35, 6)

# %%
circuits_df.head()
# Out:
#         circuitId                     circuitName      lat       long  \
# 0     albert_park  Albert Park Grand Prix Circuit -37.8497  144.96800
# 1         bahrain   Bahrain International Circuit  26.0325   50.51060
# 2       catalunya  Circuit de Barcelona-Catalunya  41.5700    2.26111
# 3  hockenheimring                  Hockenheimring  49.3278    8.56583
# 4     hungaroring                     Hungaroring  47.5789   19.24860
#
#      locality    country
# 0   Melbourne  Australia
# 1      Sakhir    Bahrain
# 2   Barcelona      Spain
# 3  Hockenheim    Germany
# 4    Budapest    Hungary

# %%
import requests
from src.utils import logger

# %%
# One single API call — not 16
url = "http://ergast.com/api/f1/drivers.json"

try:
    response = requests.get(url, timeout=100)
    response.raise_for_status()
    data = response.json()
except Exception as e:
    raise(e)

drivers_raw = data["MRData"]["DriverTable"]["Drivers"]

# Build DataFrame from list directly — no loop concat
records = []
for d in drivers_raw:
    records.append({
        "driver_ref":    d.get("driverId"),
        "driver_code":   d.get("code"),
        "driver_number": d.get("permanentNumber"),
        "forename":      d.get("givenName"),
        "surname":       d.get("familyName"),
        "nationality":   d.get("nationality"),
        "date_of_birth": d.get("dateOfBirth"),
    })
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[84], line 9
#       5     response = requests.get(url, timeout=100)
#       6     response.raise_for_status()
#       7     data = response.json()
#       8 except Exception as e:
# ----> 9     raise(e)
#      10
#      11 drivers_raw = data["MRData"]["DriverTable"]["Drivers"]
#      12
#
# Cell In[84], line 9
#       5     response = requests.get(url, timeout=100)
#       6     response.raise_for_status()
#       7     data = response.json()
#       8 except Exception as e:
# ----> 9     raise(e)
#      10
#      11 drivers_raw = data["MRData"]["DriverTable"]["Drivers"]
#      12
#
# File c:\Users\Asus\Desktop\Formula1_exp\env\Lib\site-packages\requests\models.py:1167, in Response.raise_for_status(self)
#    1162     http_error_msg = (
#    1163         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1164     )
#    1166 if http_error_msg:
# -> 1167     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 520 Server Error: <none> for url: https://ergast.com/api/f1/drivers.json

# %%
import requests

url = "https://api.jolpi.ca/ergast/f1/drivers.json?limit=1000"

response = requests.get(url, timeout=30)
response.raise_for_status()

data = response.json()

# %%
data
# Out:
# {'MRData': {'xmlns': '',
#   'series': 'f1',
#   'url': 'https://api.jolpi.ca/ergast/f1/drivers.json',
#   'limit': '100',
#   'offset': '0',
#   'total': '879',
#   'DriverTable': {'Drivers': [{'driverId': 'abate',
#      'url': 'http://en.wikipedia.org/wiki/Carlo_Mario_Abate',
#      'givenName': 'Carlo',
#      'familyName': 'Abate',
#      'dateOfBirth': '1932-07-10',
#      'nationality': 'Italian'},
#     {'driverId': 'abecassis',
#      'url': 'http://en.wikipedia.org/wiki/George_Abecassis',
#      'givenName': 'George',
#      'familyName': 'Abecassis',
#      'dateOfBirth': '1913-03-21',
#      'nationality': 'British'},
#     {'driverId': 'acheson',
#      'url': 'http://en.wikipedia.org/wiki/Kenny_Acheson',
#      'givenName': 'Kenny',
#      'familyName': 'Acheson',
#      'dateOfBirth': '1957-11-27',
#      'nationality': 'British'},
#     {'driverId': 'adams',
#      'url': 'http://en.wikipedia.org/wiki/Philippe_Adams',
#      'givenName': 'Philippe',
#      'familyName': 'Adams',
#      'dateOfBirth': '1969-11-19',
#      'nationality': 'Belgian'},
#     {'driverId': 'ader',
#      'url': 'http://en.wikipedia.org/wiki/Walt_Ader',
#      'givenName': 'Walt',
#      'familyName': 'Ader',
#      'dateOfBirth': '1913-12-15',
#      'nationality': 'American'},
#     {'driverId': 'adolff',
#      'url': 'http://en.wikipedia.org/wiki/Kurt_Adolff',
#      'givenName': 'Kurt',
#      'familyName': 'Adolff',
#      'dateOfBirth': '1921-11-05',
#      'nationality': 'German'},
#     {'driverId': 'agabashian',
#      'url': 'http://en.wikipedia.org/wiki/Fred_Agabashian',
#      'givenName': 'Fred',
#      'familyName': 'Agabashian',
#      'dateOfBirth': '1913-08-21',
#      'nationality': 'American'},
#     {'driverId': 'ahrens',
#      'url': 'http://en.wikipedia.org/wiki/Kurt_Ahrens,_Jr.',
#      'givenName': 'Kurt',
#      'familyName': 'Ahrens',
#      'dateOfBirth': '1940-04-19',
#      'nationality': 'German'},
#     {'driverId': 'aitken',
#      'permanentNumber': '89',
#      'code': 'AIT',
#      'url': 'http://en.wikipedia.org/wiki/Jack_Aitken',
#      'givenName': 'Jack',
#      'familyName': 'Aitken',
#      'dateOfBirth': '1995-09-23',
#      'nationality': 'British'},
#     {'driverId': 'albers',
#      'code': 'ALB',
#      'url': 'http://en.wikipedia.org/wiki/Christijan_Albers',
#      'givenName': 'Christijan',
#      'familyName': 'Albers',
#      'dateOfBirth': '1979-04-16',
#      'nationality': 'Dutch'},
#     {'driverId': 'albon',
#      'permanentNumber': '23',
#      'code': 'ALB',
#      'url': 'http://en.wikipedia.org/wiki/Alexander_Albon',
#      'givenName': 'Alexander',
#      'familyName': 'Albon',
#      'dateOfBirth': '1996-03-23',
#      'nationality': 'Thai'},
#     {'driverId': 'alboreto',
#      'url': 'http://en.wikipedia.org/wiki/Michele_Alboreto',
#      'givenName': 'Michele',
#      'familyName': 'Alboreto',
#      'dateOfBirth': '1956-12-23',
#      'nationality': 'Italian'},
#     {'driverId': 'alesi',
#      'url': 'http://en.wikipedia.org/wiki/Jean_Alesi',
#      'givenName': 'Jean',
#      'familyName': 'Alesi',
#      'dateOfBirth': '1964-06-11',
#      'nationality': 'French'},
#     {'driverId': 'alguersuari',
#      'code': 'ALG',
#      'url': 'http://en.wikipedia.org/wiki/Jaime_Alguersuari',
#      'givenName': 'Jaime',
#      'familyName': 'Alguersuari',
#      'dateOfBirth': '1990-03-23',
#      'nationality': 'Spanish'},
#     {'driverId': 'alliot',
#      'url': 'http://en.wikipedia.org/wiki/Philippe_Alliot',
#      'givenName': 'Philippe',
#      'familyName': 'Alliot',
#      'dateOfBirth': '1954-07-27',
#      'nationality': 'French'},
#     {'driverId': 'allison',
#      'url': 'http://en.wikipedia.org/wiki/Cliff_Allison',
#      'givenName': 'Cliff',
#      'familyName': 'Allison',
#      'dateOfBirth': '1932-02-08',
#      'nationality': 'British'},
#     {'driverId': 'alonso',
#      'permanentNumber': '14',
#      'code': 'ALO',
#      'url': 'http://en.wikipedia.org/wiki/Fernando_Alonso',
#      'givenName': 'Fernando',
#      'familyName': 'Alonso',
#      'dateOfBirth': '1981-07-29',
#      'nationality': 'Spanish'},
#     {'driverId': 'amati',
#      'url': 'http://en.wikipedia.org/wiki/Giovanna_Amati',
#      'givenName': 'Giovanna',
#      'familyName': 'Amati',
#      'dateOfBirth': '1959-07-20',
#      'nationality': 'Italian'},
#     {'driverId': 'george_amick',
#      'url': 'http://en.wikipedia.org/wiki/George_Amick',
#      'givenName': 'George',
#      'familyName': 'Amick',
#      'dateOfBirth': '1924-10-24',
#      'nationality': 'American'},
#     {'driverId': 'amick',
#      'url': 'http://en.wikipedia.org/wiki/Red_Amick',
#      'givenName': 'Red',
#      'familyName': 'Amick',
#      'dateOfBirth': '1929-01-19',
#      'nationality': 'American'},
#     {'driverId': 'amon',
#      'url': 'http://en.wikipedia.org/wiki/Chris_Amon',
#      'givenName': 'Chris',
#      'familyName': 'Amon',
#      'dateOfBirth': '1943-07-20',
#      'nationality': 'New Zealander'},
#     {'driverId': 'anderson',
#      'url': 'http://en.wikipedia.org/wiki/Bob_Anderson_(racing_driver)',
#      'givenName': 'Bob',
#      'familyName': 'Anderson',
#      'dateOfBirth': '1931-05-19',
#      'nationality': 'British'},
#     {'driverId': 'andersson',
#      'url': 'http://en.wikipedia.org/wiki/Conny_Andersson_(racing_driver)',
#      'givenName': 'Conny',
#      'familyName': 'Andersson',
#      'dateOfBirth': '1939-12-28',
#      'nationality': 'Swedish'},
#     {'driverId': 'mario_andretti',
#      'url': 'http://en.wikipedia.org/wiki/Mario_Andretti',
#      'givenName': 'Mario',
#      'familyName': 'Andretti',
#      'dateOfBirth': '1940-02-28',
#      'nationality': 'American'},
#     {'driverId': 'andretti',
#      'url': 'http://en.wikipedia.org/wiki/Michael_Andretti',
#      'givenName': 'Michael',
#      'familyName': 'Andretti',
#      'dateOfBirth': '1962-10-05',
#      'nationality': 'American'},
#     {'driverId': 'andrews',
#      'url': 'http://en.wikipedia.org/wiki/Keith_Andrews_(driver)',
#      'givenName': 'Keith',
#      'familyName': 'Andrews',
#      'dateOfBirth': '1920-06-15',
#      'nationality': 'American'},
#     {'driverId': 'antonelli',
#      'permanentNumber': '12',
#      'code': 'ANT',
#      'url': 'https://en.wikipedia.org/wiki/Andrea_Kimi_Antonelli',
#      'givenName': 'Andrea Kimi',
#      'familyName': 'Antonelli',
#      'dateOfBirth': '2006-08-25',
#      'nationality': 'Italian'},
#     {'driverId': 'apicella',
#      'url': 'http://en.wikipedia.org/wiki/Marco_Apicella',
#      'givenName': 'Marco',
#      'familyName': 'Apicella',
#      'dateOfBirth': '1965-10-07',
#      'nationality': 'Italian'},
#     {'driverId': 'armi',
#      'url': 'http://en.wikipedia.org/wiki/Frank_Armi',
#      'givenName': 'Frank',
#      'familyName': 'Armi',
#      'dateOfBirth': '1918-10-12',
#      'nationality': 'American'},
#     {'driverId': 'arnold',
#      'url': 'http://en.wikipedia.org/wiki/Chuck_Arnold',
#      'givenName': 'Chuck',
#      'familyName': 'Arnold',
#      'dateOfBirth': '1926-05-30',
#      'nationality': 'American'},
#     {'driverId': 'arnoux',
#      'url': 'http://en.wikipedia.org/wiki/Ren%C3%A9_Arnoux',
#      'givenName': 'René',
#      'familyName': 'Arnoux',
#      'dateOfBirth': '1948-07-04',
#      'nationality': 'French'},
#     {'driverId': 'paul_aron', 'givenName': 'Paul', 'familyName': 'Aron'},
#     {'driverId': 'arundell',
#      'url': 'http://en.wikipedia.org/wiki/Peter_Arundell',
#      'givenName': 'Peter',
#      'familyName': 'Arundell',
#      'dateOfBirth': '1933-11-08',
#      'nationality': 'British'},
#     {'driverId': 'ascari',
#      'url': 'http://en.wikipedia.org/wiki/Alberto_Ascari',
#      'givenName': 'Alberto',
#      'familyName': 'Ascari',
#      'dateOfBirth': '1918-07-13',
#      'nationality': 'Italian'},
#     {'driverId': 'ashdown',
#      'url': 'http://en.wikipedia.org/wiki/Peter_Ashdown',
#      'givenName': 'Peter',
#      'familyName': 'Ashdown',
#      'dateOfBirth': '1934-10-16',
#      'nationality': 'British'},
#     {'driverId': 'ashley',
#      'url': 'http://en.wikipedia.org/wiki/Ian_Ashley',
#      'givenName': 'Ian',
#      'familyName': 'Ashley',
#      'dateOfBirth': '1947-10-26',
#      'nationality': 'British'},
#     {'driverId': 'ashmore',
#      'url': 'http://en.wikipedia.org/wiki/Gerry_Ashmore',
#      'givenName': 'Gerry',
#      'familyName': 'Ashmore',
#      'dateOfBirth': '1936-07-25',
#      'nationality': 'British'},
#     {'driverId': 'aston',
#      'url': 'http://en.wikipedia.org/wiki/Bill_Aston',
#      'givenName': 'Bill',
#      'familyName': 'Aston',
#      'dateOfBirth': '1900-03-29',
#      'nationality': 'British'},
#     {'driverId': 'attwood',
#      'url': 'http://en.wikipedia.org/wiki/Richard_Attwood',
#      'givenName': 'Richard',
#      'familyName': 'Attwood',
#      'dateOfBirth': '1940-04-04',
#      'nationality': 'British'},
#     {'driverId': 'ayulo',
#      'url': 'http://en.wikipedia.org/wiki/Manny_Ayulo',
#      'givenName': 'Manny',
#      'familyName': 'Ayulo',
#      'dateOfBirth': '1921-10-20',
#      'nationality': 'American'},
#     {'driverId': 'badoer',
#      'code': 'BAD',
#      'url': 'http://en.wikipedia.org/wiki/Luca_Badoer',
#      'givenName': 'Luca',
#      'familyName': 'Badoer',
#      'dateOfBirth': '1971-01-25',
#      'nationality': 'Italian'},
#     {'driverId': 'baghetti',
#      'url': 'http://en.wikipedia.org/wiki/Giancarlo_Baghetti',
#      'givenName': 'Giancarlo',
#      'familyName': 'Baghetti',
#      'dateOfBirth': '1934-12-25',
#      'nationality': 'Italian'},
#     {'driverId': 'bailey',
#      'url': 'http://en.wikipedia.org/wiki/Julian_Bailey',
#      'givenName': 'Julian',
#      'familyName': 'Bailey',
#      'dateOfBirth': '1961-10-09',
#      'nationality': 'British'},
#     {'driverId': 'baldi',
#      'url': 'http://en.wikipedia.org/wiki/Mauro_Baldi',
#      'givenName': 'Mauro',
#      'familyName': 'Baldi',
#      'dateOfBirth': '1954-01-31',
#      'nationality': 'Italian'},
#     {'driverId': 'ball',
#      'url': 'http://en.wikipedia.org/wiki/Bobby_Ball_(auto_racer)',
#      'givenName': 'Bobby',
#      'familyName': 'Ball',
#      'dateOfBirth': '1925-08-26',
#      'nationality': 'American'},
#     {'driverId': 'balsa',
#      'url': 'http://en.wikipedia.org/wiki/Marcel_Balsa',
#      'givenName': 'Marcel',
#      'familyName': 'Balsa',
#      'dateOfBirth': '1909-01-01',
#      'nationality': 'French'},
#     {'driverId': 'bandini',
#      'url': 'http://en.wikipedia.org/wiki/Lorenzo_Bandini',
#      'givenName': 'Lorenzo',
#      'familyName': 'Bandini',
#      'dateOfBirth': '1935-12-21',
#      'nationality': 'Italian'},
#     {'driverId': 'banks',
#      'url': 'http://en.wikipedia.org/wiki/Henry_Banks',
#      'givenName': 'Henry',
#      'familyName': 'Banks',
#      'dateOfBirth': '1913-06-14',
#      'nationality': 'American'},
#     {'driverId': 'barbazza',
#      'url': 'http://en.wikipedia.org/wiki/Fabrizio_Barbazza',
#      'givenName': 'Fabrizio',
#      'familyName': 'Barbazza',
#      'dateOfBirth': '1963-04-02',
#      'nationality': 'Italian'},
#     {'driverId': 'john_barber',
#      'url': 'http://en.wikipedia.org/wiki/John_Barber_(racing_driver)',
#      'givenName': 'John',
#      'familyName': 'Barber',
#      'dateOfBirth': '1929-07-22',
#      'nationality': 'British'},
#     {'driverId': 'barber',
#      'url': 'http://en.wikipedia.org/wiki/Skip_Barber',
#      'givenName': 'Skip',
#      'familyName': 'Barber',
#      'dateOfBirth': '1936-11-16',
#      'nationality': 'American'},
#     {'driverId': 'barilla',
#      'url': 'http://en.wikipedia.org/wiki/Paolo_Barilla',
#      'givenName': 'Paolo',
#      'familyName': 'Barilla',
#      'dateOfBirth': '1961-04-20',
#      'nationality': 'Italian'},
#     {'driverId': 'barrichello',
#      'code': 'BAR',
#      'url': 'http://en.wikipedia.org/wiki/Rubens_Barrichello',
#      'givenName': 'Rubens',
#      'familyName': 'Barrichello',
#      'dateOfBirth': '1972-05-23',
#      'nationality': 'Brazilian'},
#     {'driverId': 'bartels',
#      'url': 'http://en.wikipedia.org/wiki/Michael_Bartels',
#      'givenName': 'Michael',
#      'familyName': 'Bartels',
#      'dateOfBirth': '1968-03-08',
#      'nationality': 'German'},
#     {'driverId': 'barth',
#      'url': 'http://en.wikipedia.org/wiki/Edgar_Barth',
#      'givenName': 'Edgar',
#      'familyName': 'Barth',
#      'dateOfBirth': '1917-01-26',
#      'nationality': 'German'},
#     {'driverId': 'bassi',
#      'url': 'http://en.wikipedia.org/wiki/Giorgio_Bassi',
#      'givenName': 'Giorgio',
#      'familyName': 'Bassi',
#      'dateOfBirth': '1934-01-20',
#      'nationality': 'Italian'},
#     {'driverId': 'bauer',
#      'url': 'http://en.wikipedia.org/wiki/Erwin_Bauer',
#      'givenName': 'Erwin',
#      'familyName': 'Bauer',
#      'dateOfBirth': '1912-07-17',
#      'nationality': 'German'},
#     {'driverId': 'baumgartner',
#      'url': 'http://en.wikipedia.org/wiki/Zsolt_Baumgartner',
#      'givenName': 'Zsolt',
#      'familyName': 'Baumgartner',
#      'dateOfBirth': '1981-01-01',
#      'nationality': 'Hungarian'},
#     {'driverId': 'bayol',
#      'url': 'http://en.wikipedia.org/wiki/%C3%89lie_Bayol',
#      'givenName': 'Élie',
#      'familyName': 'Bayol',
#      'dateOfBirth': '1914-02-28',
#      'nationality': 'French'},
#     {'driverId': 'bearman',
#      'permanentNumber': '87',
#      'code': 'BEA',
#      'url': 'http://en.wikipedia.org/wiki/Oliver_Bearman',
#      'givenName': 'Oliver',
#      'familyName': 'Bearman',
#      'dateOfBirth': '2005-05-08',
#      'nationality': 'British'},
#     {'driverId': 'beauman',
#      'url': 'http://en.wikipedia.org/wiki/Don_Beauman',
#      'givenName': 'Don',
#      'familyName': 'Beauman',
#      'dateOfBirth': '1928-07-26',
#      'nationality': 'British'},
#     {'driverId': 'bechem',
#      'url': 'http://en.wikipedia.org/wiki/G%C3%BCnther_Bechem',
#      'givenName': 'Günther',
#      'familyName': 'Bechem',
#      'dateOfBirth': '1921-12-21',
#      'nationality': 'German'},
#     {'driverId': 'dino_beganovic',
#      'givenName': 'Dino',
#      'familyName': 'Beganovic'},
#     {'driverId': 'behra',
#      'url': 'http://en.wikipedia.org/wiki/Jean_Behra',
#      'givenName': 'Jean',
#      'familyName': 'Behra',
#      'dateOfBirth': '1921-02-16',
#      'nationality': 'French'},
#     {'driverId': 'bell',
#      'url': 'http://en.wikipedia.org/wiki/Derek_Bell_(auto_racer)',
#      'givenName': 'Derek',
#      'familyName': 'Bell',
#      'dateOfBirth': '1941-10-31',
#      'nationality': 'British'},
#     {'driverId': 'bellof',
#      'url': 'http://en.wikipedia.org/wiki/Stefan_Bellof',
#      'givenName': 'Stefan',
#      'familyName': 'Bellof',
#      'dateOfBirth': '1957-11-20',
#      'nationality': 'German'},
#     {'driverId': 'belmondo',
#      'url': 'http://en.wikipedia.org/wiki/Paul_Belmondo',
#      'givenName': 'Paul',
#      'familyName': 'Belmondo',
#      'dateOfBirth': '1963-04-23',
#      'nationality': 'French'},
#     {'driverId': 'belso',
#      'url': 'http://en.wikipedia.org/wiki/Tom_Bels%C3%B8',
#      'givenName': 'Tom',
#      'familyName': 'Belsø',
#      'dateOfBirth': '1942-08-27',
#      'nationality': 'Danish'},
#     {'driverId': 'beltoise',
#      'url': 'http://en.wikipedia.org/wiki/Jean-Pierre_Beltoise',
#      'givenName': 'Jean-Pierre',
#      'familyName': 'Beltoise',
#      'dateOfBirth': '1937-04-26',
#      'nationality': 'French'},
#     {'driverId': 'beretta',
#      'url': 'http://en.wikipedia.org/wiki/Olivier_Beretta',
#      'givenName': 'Olivier',
#      'familyName': 'Beretta',
#      'dateOfBirth': '1969-11-23',
#      'nationality': 'Monegasque'},
#     {'driverId': 'berg',
#      'url': 'http://en.wikipedia.org/wiki/Allen_Berg',
#      'givenName': 'Allen',
#      'familyName': 'Berg',
#      'dateOfBirth': '1961-08-01',
#      'nationality': 'Canadian'},
#     {'driverId': 'georges_berger',
#      'url': 'http://en.wikipedia.org/wiki/Georges_Berger',
#      'givenName': 'Georges',
#      'familyName': 'Berger',
#      'dateOfBirth': '1918-09-14',
#      'nationality': 'Belgian'},
#     {'driverId': 'berger',
#      'url': 'http://en.wikipedia.org/wiki/Gerhard_Berger',
#      'givenName': 'Gerhard',
#      'familyName': 'Berger',
#      'dateOfBirth': '1959-08-27',
#      'nationality': 'Austrian'},
#     {'driverId': 'bernard',
#      'url': 'http://en.wikipedia.org/wiki/%C3%89ric_Bernard',
#      'givenName': 'Éric',
#      'familyName': 'Bernard',
#      'dateOfBirth': '1964-08-24',
#      'nationality': 'French'},
#     {'driverId': 'bernoldi',
#      'url': 'http://en.wikipedia.org/wiki/Enrique_Bernoldi',
#      'givenName': 'Enrique',
#      'familyName': 'Bernoldi',
#      'dateOfBirth': '1978-10-19',
#      'nationality': 'Brazilian'},
#     {'driverId': 'bertaggia',
#      'url': 'http://en.wikipedia.org/wiki/Enrico_Bertaggia',
#      'givenName': 'Enrico',
#      'familyName': 'Bertaggia',
#      'dateOfBirth': '1964-09-19',
#      'nationality': 'Italian'},
#     {'driverId': 'bettenhausen',
#      'url': 'http://en.wikipedia.org/wiki/Tony_Bettenhausen',
#      'givenName': 'Tony',
#      'familyName': 'Bettenhausen',
#      'dateOfBirth': '1916-09-12',
#      'nationality': 'American'},
#     {'driverId': 'beuttler',
#      'url': 'http://en.wikipedia.org/wiki/Mike_Beuttler',
#      'givenName': 'Mike',
#      'familyName': 'Beuttler',
#      'dateOfBirth': '1940-04-13',
#      'nationality': 'British'},
#     {'driverId': 'bianchi',
#      'url': 'http://en.wikipedia.org/wiki/Lucien_Bianchi',
#      'givenName': 'Lucien',
#      'familyName': 'Bianchi',
#      'dateOfBirth': '1934-11-10',
#      'nationality': 'Belgian'},
#     {'driverId': 'jules_bianchi',
#      'permanentNumber': '17',
#      'code': 'BIA',
#      'url': 'http://en.wikipedia.org/wiki/Jules_Bianchi',
#      'givenName': 'Jules',
#      'familyName': 'Bianchi',
#      'dateOfBirth': '1989-08-03',
#      'nationality': 'French'},
#     {'driverId': 'bianco',
#      'url': 'http://en.wikipedia.org/wiki/Gino_Bianco',
#      'givenName': 'Gino',
#      'familyName': 'Bianco',
#      'dateOfBirth': '1916-07-22',
#      'nationality': 'Brazilian'},
#     {'driverId': 'binder',
#      'url': 'http://en.wikipedia.org/wiki/Hans_Binder',
#      'givenName': 'Hans',
#      'familyName': 'Binder',
#      'dateOfBirth': '1948-06-12',
#      'nationality': 'Austrian'},
#     {'driverId': 'biondetti',
#      'url': 'http://en.wikipedia.org/wiki/Clemente_Biondetti',
#      'givenName': 'Clemente',
#      'familyName': 'Biondetti',
#      'dateOfBirth': '1898-08-18',
#      'nationality': 'Italian'},
#     {'driverId': 'bira',
#      'url': 'http://en.wikipedia.org/wiki/Prince_Bira',
#      'givenName': 'Prince',
#      'familyName': 'Bira',
#      'dateOfBirth': '1914-07-15',
#      'nationality': 'Thai'},
#     {'driverId': 'birger',
#      'url': 'http://en.wikipedia.org/wiki/Pablo_Birger',
#      'givenName': 'Pablo',
#      'familyName': 'Birger',
#      'dateOfBirth': '1924-01-07',
#      'nationality': 'Argentine'},
#     {'driverId': 'bisch',
#      'url': 'http://en.wikipedia.org/wiki/Art_Bisch',
#      'givenName': 'Art',
#      'familyName': 'Bisch',
#      'dateOfBirth': '1926-11-10',
#      'nationality': 'American'},
#     {'driverId': 'blanchard',
#      'url': 'http://en.wikipedia.org/wiki/Harry_Blanchard',
#      'givenName': 'Harry',
#      'familyName': 'Blanchard',
#      'dateOfBirth': '1929-06-13',
#      'nationality': 'American'},
#     {'driverId': 'bleekemolen',
#      'url': 'http://en.wikipedia.org/wiki/Michael_Bleekemolen',
#      'givenName': 'Michael',
#      'familyName': 'Bleekemolen',
#      'dateOfBirth': '1949-10-02',
#      'nationality': 'Dutch'},
#     {'driverId': 'blignaut',
#      'url': 'http://en.wikipedia.org/wiki/Alex_Blignaut',
#      'givenName': 'Alex',
#      'familyName': 'Blignaut',
#      'dateOfBirth': '1932-11-30',
#      'nationality': 'South African'},
#     {'driverId': 'blokdyk',
#      'url': 'http://en.wikipedia.org/wiki/Trevor_Blokdyk',
#      'givenName': 'Trevor',
#      'familyName': 'Blokdyk',
#      'dateOfBirth': '1935-11-30',
#      'nationality': 'South African'},
#     {'driverId': 'blundell',
#      'url': 'http://en.wikipedia.org/wiki/Mark_Blundell',
#      'givenName': 'Mark',
#      'familyName': 'Blundell',
#      'dateOfBirth': '1966-04-08',
#      'nationality': 'British'},
#     {'driverId': 'boesel',
#      'url': 'http://en.wikipedia.org/wiki/Raul_Boesel',
#      'givenName': 'Raul',
#      'familyName': 'Boesel',
#      'dateOfBirth': '1957-12-04',
#      'nationality': 'Brazilian'},
#     {'driverId': 'boffa',
#      'url': 'http://en.wikipedia.org/wiki/Menato_Boffa',
#      'givenName': 'Menato',
#      'familyName': 'Boffa',
#      'dateOfBirth': '1930-01-04',
#      'nationality': 'Italian'},
#     {'driverId': 'bondurant',
#      'url': 'http://en.wikipedia.org/wiki/Bob_Bondurant',
#      'givenName': 'Bob',
#      'familyName': 'Bondurant',
#      'dateOfBirth': '1933-04-27',
#      'nationality': 'American'},
#     {'driverId': 'bonetto',
#      'url': 'http://en.wikipedia.org/wiki/Felice_Bonetto',
#      'givenName': 'Felice',
#      'familyName': 'Bonetto',
#      'dateOfBirth': '1903-06-09',
#      'nationality': 'Italian'},
#     {'driverId': 'bonnier',
#      'url': 'http://en.wikipedia.org/wiki/Joakim_Bonnier',
#      'givenName': 'Jo',
#      'familyName': 'Bonnier',
#      'dateOfBirth': '1930-01-31',
#      'nationality': 'Swedish'},
#     {'driverId': 'bonomi',
#      'url': 'http://en.wikipedia.org/wiki/Roberto_Bonomi',
#      'givenName': 'Roberto',
#      'familyName': 'Bonomi',
#      'dateOfBirth': '1919-09-30',
#      'nationality': 'Argentine'},
#     {'driverId': 'bordeu',
#      'url': 'http://en.wikipedia.org/wiki/Juan_Manuel_Bordeu',
#      'givenName': 'Juan Manuel',
#      'familyName': 'Bordeu',
#      'dateOfBirth': '1934-01-28',
#      'nationality': 'Argentine'},
#     {'driverId': 'borgudd',
#      'url': 'http://en.wikipedia.org/wiki/Slim_Borgudd',
#      'givenName': 'Slim',
#      'familyName': 'Borgudd',
#      'dateOfBirth': '1946-11-25',
#      'nationality': 'Swedish'},
#     {'driverId': 'bortoleto',
#      'permanentNumber': '5',
#      'code': 'BOR',
#      'url': 'https://en.wikipedia.org/wiki/Gabriel_Bortoleto',
#      'givenName': 'Gabriel',
#      'familyName': 'Bortoleto',
#      'dateOfBirth': '2004-10-14',
#      'nationality': 'Brazilian'}]}}}

# %%
import pandas as pd

drivers_raw = data["MRData"]["total"]

drivers_raw
# Out:
# '879'

# %%
df.shape
# Out:
# (100, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   driverId         100 non-null    object
#  1   url              98 non-null     object
#  2   givenName        100 non-null    object
#  3   familyName       100 non-null    object
#  4   dateOfBirth      98 non-null     object
#  5   nationality      98 non-null     object
#  6   permanentNumber  7 non-null      object
#  7   code             11 non-null     object
# dtypes: object(8)
# memory usage: 6.4+ KB

# %%
df.to_csv("data+drivers.csv")

# %%
# ── Config ────────────────────────────────────────────────────────────────────
BASE_URL   = "https://api.jolpi.ca/ergast/f1"
 
# ── Fetch ─────────────────────────────────────────────────────────────────────
print("Fetching all F1 drivers...")
 
url      = f"{BASE_URL}/drivers.json?limit=1000&offset=0"
response = requests.get(url, timeout=30)
response.raise_for_status()
 
data    = response.json()
drivers = data["MRData"]["DriverTable"]["Drivers"]
print(f"Total drivers fetched: {len(drivers)}")
 
# ── Build DataFrame ───────────────────────────────────────────────────────────
records = []
for d in drivers:
    records.append({
        "driver_ref":    d.get("driverId"),
        "driver_code":   d.get("code"),
        "driver_number": d.get("permanentNumber"),
        "forename":      d.get("givenName"),
        "surname":       d.get("familyName"),
        "date_of_birth": d.get("dateOfBirth"),
        "nationality":   d.get("nationality"),
    })
 
df = pd.DataFrame(records)
 
# ── Clean ─────────────────────────────────────────────────────────────────────
# Remove duplicate drivers
df = df.drop_duplicates(subset=["driver_ref"])
# Out:
# Fetching all F1 drivers...
# Total drivers fetched: 100

# %%
df.to_csv("hcvjh.csv")

# %%
import requests
import pandas as pd
from pathlib import Path

BASE_URL  = "https://api.jolpi.ca/ergast/f1"

# ── Fetch all pages ───────────────────────────────────────────────────────────
print("Fetching all F1 drivers...")

all_drivers = []
limit       = 100   # fetch 100 per page
offset      = 0

while True:
    url      = f"{BASE_URL}/drivers.json?limit={limit}&offset={offset}"
    response = requests.get(url, timeout=30)
    response.raise_for_status()
    data     = response.json()

    drivers = data["MRData"]["DriverTable"]["Drivers"]
    total   = int(data["MRData"]["total"])

    all_drivers.extend(drivers)
    print(f"  Fetched {len(all_drivers)}/{total} drivers...")

    offset += limit
    if offset >= total:
        break

print(f"Total drivers fetched: {len(all_drivers)}")

# ── Build DataFrame ───────────────────────────────────────────────────────────
records = []
for d in all_drivers:
    records.append({
        "driver_ref":    d.get("driverId"),
        "driver_code":   d.get("code"),
        "driver_number": d.get("permanentNumber"),
        "forename":      d.get("givenName"),
        "surname":       d.get("familyName"),
        "date_of_birth": d.get("dateOfBirth"),
        "nationality":   d.get("nationality"),
    })

df = pd.DataFrame(records)

# ── Clean ─────────────────────────────────────────────────────────────────────
df = df.drop_duplicates(subset=["driver_ref"])
# Out:
# Fetching all F1 drivers...
#   Fetched 100/879 drivers...
#   Fetched 200/879 drivers...
#   Fetched 300/879 drivers...
#   Fetched 400/879 drivers...
#   Fetched 500/879 drivers...
#   Fetched 600/879 drivers...
#   Fetched 700/879 drivers...
#   Fetched 800/879 drivers...
#   Fetched 879/879 drivers...
# Total drivers fetched: 879

# %%
df[df["surname"].isin(["Verstappen","Leclerc","Hamilton","Norris"])]
# Out:
#           driver_ref driver_code driver_number forename     surname  \
# 333  duncan_hamilton        None          None   Duncan    Hamilton
# 334         hamilton         HAM            44    Lewis    Hamilton
# 444          leclerc         LEC            16  Charles     Leclerc
# 445   arthur_leclerc        None          None   Arthur     Leclerc
# 559           norris         NOR             1    Lando      Norris
# 790       verstappen        None          None      Jos  Verstappen
# 791   max_verstappen         VER             3      Max  Verstappen
#
#     date_of_birth nationality
# 333    1920-04-30     British
# 334    1985-01-07     British
# 444    1997-10-16  Monegasque
# 445          None        None
# 559    1999-11-13     British
# 790    1972-03-04       Dutch
# 791    1997-09-30       Dutch

# %%
year = 2024

# %%
BASE_URL = "https://api.jolpi.ca/ergast/f1"

# %%
import requests

# %%
url = f"{BASE_URL}/{year}/races.json?limit=30"
try:
    response = requests.get(url, timeout=30)
    response.raise_for_status()
    races = response.json()["MRData"]["RaceTable"]["Races"]
except Exception as e:
    raise(e)

# %%
len(races)
# Out:
# 24

# %%
races
# Out:
# [{'season': '2024',
#   'round': '1',
#   'url': 'https://en.wikipedia.org/wiki/2024_Bahrain_Grand_Prix',
#   'raceName': 'Bahrain Grand Prix',
#   'Circuit': {'circuitId': 'bahrain',
#    'url': 'https://en.wikipedia.org/wiki/Bahrain_International_Circuit',
#    'circuitName': 'Bahrain International Circuit',
#    'Location': {'lat': '26.0325',
#     'long': '50.5106',
#     'locality': 'Sakhir',
#     'country': 'Bahrain'}},
#   'date': '2024-03-02',
#   'time': '15:00:00Z',
#   'FirstPractice': {'date': '2024-02-29', 'time': '11:30:00Z'},
#   'SecondPractice': {'date': '2024-02-29', 'time': '15:00:00Z'},
#   'ThirdPractice': {'date': '2024-03-01', 'time': '12:30:00Z'},
#   'Qualifying': {'date': '2024-03-01', 'time': '16:00:00Z'}},
#  {'season': '2024',
#   'round': '2',
#   'url': 'https://en.wikipedia.org/wiki/2024_Saudi_Arabian_Grand_Prix',
#   'raceName': 'Saudi Arabian Grand Prix',
#   'Circuit': {'circuitId': 'jeddah',
#    'url': 'https://en.wikipedia.org/wiki/Jeddah_Corniche_Circuit',
#    'circuitName': 'Jeddah Corniche Circuit',
#    'Location': {'lat': '21.6319',
#     'long': '39.1044',
#     'locality': 'Jeddah',
#     'country': 'Saudi Arabia'}},
#   'date': '2024-03-09',
#   'time': '17:00:00Z',
#   'FirstPractice': {'date': '2024-03-07', 'time': '13:30:00Z'},
#   'SecondPractice': {'date': '2024-03-07', 'time': '17:00:00Z'},
#   'ThirdPractice': {'date': '2024-03-08', 'time': '13:30:00Z'},
#   'Qualifying': {'date': '2024-03-08', 'time': '17:00:00Z'}},
#  {'season': '2024',
#   'round': '3',
#   'url': 'https://en.wikipedia.org/wiki/2024_Australian_Grand_Prix',
#   'raceName': 'Australian Grand Prix',
#   'Circuit': {'circuitId': 'albert_park',
#    'url': 'https://en.wikipedia.org/wiki/Albert_Park_Circuit',
#    'circuitName': 'Albert Park Grand Prix Circuit',
#    'Location': {'lat': '-37.8497',
#     'long': '144.968',
#     'locality': 'Melbourne',
#     'country': 'Australia'}},
#   'date': '2024-03-24',
#   'time': '04:00:00Z',
#   'FirstPractice': {'date': '2024-03-22', 'time': '01:30:00Z'},
#   'SecondPractice': {'date': '2024-03-22', 'time': '05:00:00Z'},
#   'ThirdPractice': {'date': '2024-03-23', 'time': '01:30:00Z'},
#   'Qualifying': {'date': '2024-03-23', 'time': '05:00:00Z'}},
#  {'season': '2024',
#   'round': '4',
#   'url': 'https://en.wikipedia.org/wiki/2024_Japanese_Grand_Prix',
#   'raceName': 'Japanese Grand Prix',
#   'Circuit': {'circuitId': 'suzuka',
#    'url': 'https://en.wikipedia.org/wiki/Suzuka_International_Racing_Course',
#    'circuitName': 'Suzuka Circuit',
#    'Location': {'lat': '34.8431',
#     'long': '136.541',
#     'locality': 'Suzuka',
#     'country': 'Japan'}},
#   'date': '2024-04-07',
#   'time': '05:00:00Z',
#   'FirstPractice': {'date': '2024-04-05', 'time': '02:30:00Z'},
#   'SecondPractice': {'date': '2024-04-05', 'time': '06:00:00Z'},
#   'ThirdPractice': {'date': '2024-04-06', 'time': '02:30:00Z'},
#   'Qualifying': {'date': '2024-04-06', 'time': '06:00:00Z'}},
#  {'season': '2024',
#   'round': '5',
#   'url': 'https://en.wikipedia.org/wiki/2024_Chinese_Grand_Prix',
#   'raceName': 'Chinese Grand Prix',
#   'Circuit': {'circuitId': 'shanghai',
#    'url': 'https://en.wikipedia.org/wiki/Shanghai_International_Circuit',
#    'circuitName': 'Shanghai International Circuit',
#    'Location': {'lat': '31.3389',
#     'long': '121.22',
#     'locality': 'Shanghai',
#     'country': 'China'}},
#   'date': '2024-04-21',
#   'time': '07:00:00Z',
#   'FirstPractice': {'date': '2024-04-19', 'time': '03:30:00Z'},
#   'Qualifying': {'date': '2024-04-20', 'time': '07:00:00Z'},
#   'Sprint': {'date': '2024-04-20', 'time': '03:00:00Z'},
#   'SprintQualifying': {'date': '2024-04-19', 'time': '07:30:00Z'}},
#  {'season': '2024',
#   'round': '6',
#   'url': 'https://en.wikipedia.org/wiki/2024_Miami_Grand_Prix',
#   'raceName': 'Miami Grand Prix',
#   'Circuit': {'circuitId': 'miami',
#    'url': 'https://en.wikipedia.org/wiki/Miami_International_Autodrome',
#    'circuitName': 'Miami International Autodrome',
#    'Location': {'lat': '25.9581',
#     'long': '-80.2389',
#     'locality': 'Miami',
#     'country': 'USA'}},
#   'date': '2024-05-05',
#   'time': '20:00:00Z',
#   'FirstPractice': {'date': '2024-05-03', 'time': '16:30:00Z'},
#   'Qualifying': {'date': '2024-05-04', 'time': '20:00:00Z'},
#   'Sprint': {'date': '2024-05-04', 'time': '16:00:00Z'},
#   'SprintQualifying': {'date': '2024-05-03', 'time': '20:30:00Z'}},
#  {'season': '2024',
#   'round': '7',
#   'url': 'https://en.wikipedia.org/wiki/2024_Emilia_Romagna_Grand_Prix',
#   'raceName': 'Emilia Romagna Grand Prix',
#   'Circuit': {'circuitId': 'imola',
#    'url': 'https://en.wikipedia.org/wiki/Imola_Circuit',
#    'circuitName': 'Autodromo Enzo e Dino Ferrari',
#    'Location': {'lat': '44.3439',
#     'long': '11.7167',
#     'locality': 'Imola',
#     'country': 'Italy'}},
#   'date': '2024-05-19',
#   'time': '13:00:00Z',
#   'FirstPractice': {'date': '2024-05-17', 'time': '11:30:00Z'},
#   'SecondPractice': {'date': '2024-05-17', 'time': '15:00:00Z'},
#   'ThirdPractice': {'date': '2024-05-18', 'time': '10:30:00Z'},
#   'Qualifying': {'date': '2024-05-18', 'time': '14:00:00Z'}},
#  {'season': '2024',
#   'round': '8',
#   'url': 'https://en.wikipedia.org/wiki/2024_Monaco_Grand_Prix',
#   'raceName': 'Monaco Grand Prix',
#   'Circuit': {'circuitId': 'monaco',
#    'url': 'https://en.wikipedia.org/wiki/Circuit_de_Monaco',
#    'circuitName': 'Circuit de Monaco',
#    'Location': {'lat': '43.7347',
#     'long': '7.42056',
#     'locality': 'Monte Carlo',
#     'country': 'Monaco'}},
#   'date': '2024-05-26',
#   'time': '13:00:00Z',
#   'FirstPractice': {'date': '2024-05-24', 'time': '11:30:00Z'},
#   'SecondPractice': {'date': '2024-05-24', 'time': '15:00:00Z'},
#   'ThirdPractice': {'date': '2024-05-25', 'time': '10:30:00Z'},
#   'Qualifying': {'date': '2024-05-25', 'time': '14:00:00Z'}},
#  {'season': '2024',
#   'round': '9',
#   'url': 'https://en.wikipedia.org/wiki/2024_Canadian_Grand_Prix',
#   'raceName': 'Canadian Grand Prix',
#   'Circuit': {'circuitId': 'villeneuve',
#    'url': 'https://en.wikipedia.org/wiki/Circuit_Gilles_Villeneuve',
#    'circuitName': 'Circuit Gilles Villeneuve',
#    'Location': {'lat': '45.5',
#     'long': '-73.5228',
#     'locality': 'Montreal',
#     'country': 'Canada'}},
#   'date': '2024-06-09',
#   'time': '18:00:00Z',
#   'FirstPractice': {'date': '2024-06-07', 'time': '17:30:00Z'},
#   'SecondPractice': {'date': '2024-06-07', 'time': '21:00:00Z'},
#   'ThirdPractice': {'date': '2024-06-08', 'time': '16:30:00Z'},
#   'Qualifying': {'date': '2024-06-08', 'time': '20:00:00Z'}},
#  {'season': '2024',
#   'round': '10',
#   'url': 'https://en.wikipedia.org/wiki/2024_Spanish_Grand_Prix',
#   'raceName': 'Spanish Grand Prix',
#   'Circuit': {'circuitId': 'catalunya',
#    'url': 'https://en.wikipedia.org/wiki/Circuit_de_Barcelona-Catalunya',
#    'circuitName': 'Circuit de Barcelona-Catalunya',
#    'Location': {'lat': '41.57',
#     'long': '2.26111',
#     'locality': 'Barcelona',
#     'country': 'Spain'}},
#   'date': '2024-06-23',
#   'time': '13:00:00Z',
#   'FirstPractice': {'date': '2024-06-21', 'time': '11:30:00Z'},
#   'SecondPractice': {'date': '2024-06-21', 'time': '15:00:00Z'},
#   'ThirdPractice': {'date': '2024-06-22', 'time': '10:30:00Z'},
#   'Qualifying': {'date': '2024-06-22', 'time': '14:00:00Z'}},
#  {'season': '2024',
#   'round': '11',
#   'url': 'https://en.wikipedia.org/wiki/2024_Austrian_Grand_Prix',
#   'raceName': 'Austrian Grand Prix',
#   'Circuit': {'circuitId': 'red_bull_ring',
#    'url': 'https://en.wikipedia.org/wiki/Red_Bull_Ring',
#    'circuitName': 'Red Bull Ring',
#    'Location': {'lat': '47.2197',
#     'long': '14.7647',
#     'locality': 'Spielberg',
#     'country': 'Austria'}},
#   'date': '2024-06-30',
#   'time': '13:00:00Z',
#   'FirstPractice': {'date': '2024-06-28', 'time': '10:30:00Z'},
#   'Qualifying': {'date': '2024-06-29', 'time': '14:00:00Z'},
#   'Sprint': {'date': '2024-06-29', 'time': '10:00:00Z'},
#   'SprintQualifying': {'date': '2024-06-28', 'time': '14:30:00Z'}},
#  {'season': '2024',
#   'round': '12',
#   'url': 'https://en.wikipedia.org/wiki/2024_British_Grand_Prix',
#   'raceName': 'British Grand Prix',
#   'Circuit': {'circuitId': 'silverstone',
#    'url': 'https://en.wikipedia.org/wiki/Silverstone_Circuit',
#    'circuitName': 'Silverstone Circuit',
#    'Location': {'lat': '52.0786',
#     'long': '-1.01694',
#     'locality': 'Silverstone',
#     'country': 'UK'}},
#   'date': '2024-07-07',
#   'time': '14:00:00Z',
#   'FirstPractice': {'date': '2024-07-05', 'time': '11:30:00Z'},
#   'SecondPractice': {'date': '2024-07-05', 'time': '15:00:00Z'},
#   'ThirdPractice': {'date': '2024-07-06', 'time': '10:30:00Z'},
#   'Qualifying': {'date': '2024-07-06', 'time': '14:00:00Z'}},
#  {'season': '2024',
#   'round': '13',
#   'url': 'https://en.wikipedia.org/wiki/2024_Hungarian_Grand_Prix',
#   'raceName': 'Hungarian Grand Prix',
#   'Circuit': {'circuitId': 'hungaroring',
#    'url': 'https://en.wikipedia.org/wiki/Hungaroring',
#    'circuitName': 'Hungaroring',
#    'Location': {'lat': '47.5789',
#     'long': '19.2486',
#     'locality': 'Budapest',
#     'country': 'Hungary'}},
#   'date': '2024-07-21',
#   'time': '13:00:00Z',
#   'FirstPractice': {'date': '2024-07-19', 'time': '11:30:00Z'},
#   'SecondPractice': {'date': '2024-07-19', 'time': '15:00:00Z'},
#   'ThirdPractice': {'date': '2024-07-20', 'time': '10:30:00Z'},
#   'Qualifying': {'date': '2024-07-20', 'time': '14:00:00Z'}},
#  {'season': '2024',
#   'round': '14',
#   'url': 'https://en.wikipedia.org/wiki/2024_Belgian_Grand_Prix',
#   'raceName': 'Belgian Grand Prix',
#   'Circuit': {'circuitId': 'spa',
#    'url': 'https://en.wikipedia.org/wiki/Circuit_de_Spa-Francorchamps',
#    'circuitName': 'Circuit de Spa-Francorchamps',
#    'Location': {'lat': '50.4372',
#     'long': '5.97139',
#     'locality': 'Spa',
#     'country': 'Belgium'}},
#   'date': '2024-07-28',
#   'time': '13:00:00Z',
#   'FirstPractice': {'date': '2024-07-26', 'time': '11:30:00Z'},
#   'SecondPractice': {'date': '2024-07-26', 'time': '15:00:00Z'},
#   'ThirdPractice': {'date': '2024-07-27', 'time': '10:30:00Z'},
#   'Qualifying': {'date': '2024-07-27', 'time': '14:00:00Z'}},
#  {'season': '2024',
#   'round': '15',
#   'url': 'https://en.wikipedia.org/wiki/2024_Dutch_Grand_Prix',
#   'raceName': 'Dutch Grand Prix',
#   'Circuit': {'circuitId': 'zandvoort',
#    'url': 'https://en.wikipedia.org/wiki/Circuit_Zandvoort',
#    'circuitName': 'Circuit Park Zandvoort',
#    'Location': {'lat': '52.3888',
#     'long': '4.54092',
#     'locality': 'Zandvoort',
#     'country': 'Netherlands'}},
#   'date': '2024-08-25',
#   'time': '13:00:00Z',
#   'FirstPractice': {'date': '2024-08-23', 'time': '10:30:00Z'},
#   'SecondPractice': {'date': '2024-08-23', 'time': '14:00:00Z'},
#   'ThirdPractice': {'date': '2024-08-24', 'time': '09:30:00Z'},
#   'Qualifying': {'date': '2024-08-24', 'time': '13:00:00Z'}},
#  {'season': '2024',
#   'round': '16',
#   'url': 'https://en.wikipedia.org/wiki/2024_Italian_Grand_Prix',
#   'raceName': 'Italian Grand Prix',
#   'Circuit': {'circuitId': 'monza',
#    'url': 'https://en.wikipedia.org/wiki/Monza_Circuit',
#    'circuitName': 'Autodromo Nazionale di Monza',
#    'Location': {'lat': '45.6156',
#     'long': '9.28111',
#     'locality': 'Monza',
#     'country': 'Italy'}},
#   'date': '2024-09-01',
#   'time': '13:00:00Z',
#   'FirstPractice': {'date': '2024-08-30', 'time': '11:30:00Z'},
#   'SecondPractice': {'date': '2024-08-30', 'time': '15:00:00Z'},
#   'ThirdPractice': {'date': '2024-08-31', 'time': '10:30:00Z'},
#   'Qualifying': {'date': '2024-08-31', 'time': '14:00:00Z'}},
#  {'season': '2024',
#   'round': '17',
#   'url': 'https://en.wikipedia.org/wiki/2024_Azerbaijan_Grand_Prix',
#   'raceName': 'Azerbaijan Grand Prix',
#   'Circuit': {'circuitId': 'baku',
#    'url': 'https://en.wikipedia.org/wiki/Baku_City_Circuit',
#    'circuitName': 'Baku City Circuit',
#    'Location': {'lat': '40.3725',
#     'long': '49.8533',
#     'locality': 'Baku',
#     'country': 'Azerbaijan'}},
#   'date': '2024-09-15',
#   'time': '11:00:00Z',
#   'FirstPractice': {'date': '2024-09-13', 'time': '09:30:00Z'},
#   'SecondPractice': {'date': '2024-09-13', 'time': '13:00:00Z'},
#   'ThirdPractice': {'date': '2024-09-14', 'time': '08:30:00Z'},
#   'Qualifying': {'date': '2024-09-14', 'time': '12:00:00Z'}},
#  {'season': '2024',
#   'round': '18',
#   'url': 'https://en.wikipedia.org/wiki/2024_Singapore_Grand_Prix',
#   'raceName': 'Singapore Grand Prix',
#   'Circuit': {'circuitId': 'marina_bay',
#    'url': 'https://en.wikipedia.org/wiki/Marina_Bay_Street_Circuit',
#    'circuitName': 'Marina Bay Street Circuit',
#    'Location': {'lat': '1.2914',
#     'long': '103.864',
#     'locality': 'Marina Bay',
#     'country': 'Singapore'}},
#   'date': '2024-09-22',
#   'time': '12:00:00Z',
#   'FirstPractice': {'date': '2024-09-20', 'time': '09:30:00Z'},
#   'SecondPractice': {'date': '2024-09-20', 'time': '13:00:00Z'},
#   'ThirdPractice': {'date': '2024-09-21', 'time': '09:30:00Z'},
#   'Qualifying': {'date': '2024-09-21', 'time': '13:00:00Z'}},
#  {'season': '2024',
#   'round': '19',
#   'url': 'https://en.wikipedia.org/wiki/2024_United_States_Grand_Prix',
#   'raceName': 'United States Grand Prix',
#   'Circuit': {'circuitId': 'americas',
#    'url': 'https://en.wikipedia.org/wiki/Circuit_of_the_Americas',
#    'circuitName': 'Circuit of the Americas',
#    'Location': {'lat': '30.1328',
#     'long': '-97.6411',
#     'locality': 'Austin',
#     'country': 'USA'}},
#   'date': '2024-10-20',
#   'time': '19:00:00Z',
#   'FirstPractice': {'date': '2024-10-18', 'time': '17:30:00Z'},
#   'Qualifying': {'date': '2024-10-19', 'time': '22:00:00Z'},
#   'Sprint': {'date': '2024-10-19', 'time': '18:00:00Z'},
#   'SprintQualifying': {'date': '2024-10-18', 'time': '21:30:00Z'}},
#  {'season': '2024',
#   'round': '20',
#   'url': 'https://en.wikipedia.org/wiki/2024_Mexico_City_Grand_Prix',
#   'raceName': 'Mexico City Grand Prix',
#   'Circuit': {'circuitId': 'rodriguez',
#    'url': 'https://en.wikipedia.org/wiki/Aut%C3%B3dromo_Hermanos_Rodr%C3%ADguez',
#    'circuitName': 'Autódromo Hermanos Rodríguez',
#    'Location': {'lat': '19.4042',
#     'long': '-99.0907',
#     'locality': 'Mexico City',
#     'country': 'Mexico'}},
#   'date': '2024-10-27',
#   'time': '20:00:00Z',
#   'FirstPractice': {'date': '2024-10-25', 'time': '18:30:00Z'},
#   'SecondPractice': {'date': '2024-10-25', 'time': '22:00:00Z'},
#   'ThirdPractice': {'date': '2024-10-26', 'time': '17:30:00Z'},
#   'Qualifying': {'date': '2024-10-26', 'time': '21:00:00Z'}},
#  {'season': '2024',
#   'round': '21',
#   'url': 'https://en.wikipedia.org/wiki/2024_S%C3%A3o_Paulo_Grand_Prix',
#   'raceName': 'São Paulo Grand Prix',
#   'Circuit': {'circuitId': 'interlagos',
#    'url': 'https://en.wikipedia.org/wiki/Interlagos_Circuit',
#    'circuitName': 'Autódromo José Carlos Pace',
#    'Location': {'lat': '-23.7036',
#     'long': '-46.6997',
#     'locality': 'São Paulo',
#     'country': 'Brazil'}},
#   'date': '2024-11-03',
#   'time': '17:00:00Z',
#   'FirstPractice': {'date': '2024-11-01', 'time': '14:30:00Z'},
#   'Qualifying': {'date': '2024-11-02', 'time': '18:00:00Z'},
#   'Sprint': {'date': '2024-11-02', 'time': '14:00:00Z'},
#   'SprintQualifying': {'date': '2024-11-01', 'time': '18:30:00Z'}},
#  {'season': '2024',
#   'round': '22',
#   'url': 'https://en.wikipedia.org/wiki/2024_Las_Vegas_Grand_Prix',
#   'raceName': 'Las Vegas Grand Prix',
#   'Circuit': {'circuitId': 'vegas',
#    'url': 'https://en.wikipedia.org/wiki/Las_Vegas_Grand_Prix#Circuit',
#    'circuitName': 'Las Vegas Strip Street Circuit',
#    'Location': {'lat': '36.1147',
#     'long': '-115.173',
#     'locality': 'Las Vegas',
#     'country': 'USA'}},
#   'date': '2024-11-23',
#   'time': '06:00:00Z',
#   'FirstPractice': {'date': '2024-11-21', 'time': '02:30:00Z'},
#   'SecondPractice': {'date': '2024-11-21', 'time': '06:00:00Z'},
#   'ThirdPractice': {'date': '2024-11-22', 'time': '02:30:00Z'},
#   'Qualifying': {'date': '2024-11-22', 'time': '06:00:00Z'}},
#  {'season': '2024',
#   'round': '23',
#   'url': 'https://en.wikipedia.org/wiki/2024_Qatar_Grand_Prix',
#   'raceName': 'Qatar Grand Prix',
#   'Circuit': {'circuitId': 'losail',
#    'url': 'https://en.wikipedia.org/wiki/Lusail_International_Circuit',
#    'circuitName': 'Losail International Circuit',
#    'Location': {'lat': '25.49',
#     'long': '51.4542',
#     'locality': 'Lusail',
#     'country': 'Qatar'}},
#   'date': '2024-12-01',
#   'time': '16:00:00Z',
#   'FirstPractice': {'date': '2024-11-29', 'time': '13:30:00Z'},
#   'Qualifying': {'date': '2024-11-30', 'time': '18:00:00Z'},
#   'Sprint': {'date': '2024-11-30', 'time': '14:00:00Z'},
#   'SprintQualifying': {'date': '2024-11-29', 'time': '17:30:00Z'}},
#  {'season': '2024',
#   'round': '24',
#   'url': 'https://en.wikipedia.org/wiki/2024_Abu_Dhabi_Grand_Prix',
#   'raceName': 'Abu Dhabi Grand Prix',
#   'Circuit': {'circuitId': 'yas_marina',
#    'url': 'https://en.wikipedia.org/wiki/Yas_Marina_Circuit',
#    'circuitName': 'Yas Marina Circuit',
#    'Location': {'lat': '24.4672',
#     'long': '54.6031',
#     'locality': 'Abu Dhabi',
#     'country': 'UAE'}},
#   'date': '2024-12-08',
#   'time': '13:00:00Z',
#   'FirstPractice': {'date': '2024-12-06', 'time': '09:30:00Z'},
#   'SecondPractice': {'date': '2024-12-06', 'time': '13:00:00Z'},
#   'ThirdPractice': {'date': '2024-12-07', 'time': '10:30:00Z'},
#   'Qualifying': {'date': '2024-12-07', 'time': '14:00:00Z'}}]

# %%
races[0]
# Out:
# {'season': '2024',
#  'round': '1',
#  'url': 'https://en.wikipedia.org/wiki/2024_Bahrain_Grand_Prix',
#  'raceName': 'Bahrain Grand Prix',
#  'Circuit': {'circuitId': 'bahrain',
#   'url': 'https://en.wikipedia.org/wiki/Bahrain_International_Circuit',
#   'circuitName': 'Bahrain International Circuit',
#   'Location': {'lat': '26.0325',
#    'long': '50.5106',
#    'locality': 'Sakhir',
#    'country': 'Bahrain'}},
#  'date': '2024-03-02',
#  'time': '15:00:00Z',
#  'FirstPractice': {'date': '2024-02-29', 'time': '11:30:00Z'},
#  'SecondPractice': {'date': '2024-02-29', 'time': '15:00:00Z'},
#  'ThirdPractice': {'date': '2024-03-01', 'time': '12:30:00Z'},
#  'Qualifying': {'date': '2024-03-01', 'time': '16:00:00Z'}}

# %%
rounds = [int(r['round']) for r in races]

# %%
round_num =3

# %%
"""Fetch results for a single race round."""
url = f"{BASE_URL}/{year}/{round_num}/results.json"
try:
    response = requests.get(url, timeout=30)
    response.raise_for_status()
    races = response.json()["MRData"]["RaceTable"]["Races"]
except Exception as e:
    logger.error(f"  API call failed for {year} R{round_num:02d}: {e}")

# %%
len(races)
# Out:
# 1

# %%
races
# Out:
# [{'season': '2024',
#   'round': '3',
#   'url': 'https://en.wikipedia.org/wiki/2024_Australian_Grand_Prix',
#   'raceName': 'Australian Grand Prix',
#   'Circuit': {'circuitId': 'albert_park',
#    'url': 'https://en.wikipedia.org/wiki/Albert_Park_Circuit',
#    'circuitName': 'Albert Park Grand Prix Circuit',
#    'Location': {'lat': '-37.8497',
#     'long': '144.968',
#     'locality': 'Melbourne',
#     'country': 'Australia'}},
#   'date': '2024-03-24',
#   'time': '04:00:00Z',
#   'Results': [{'number': '55',
#     'position': '1',
#     'positionText': '1',
#     'points': '25',
#     'Driver': {'driverId': 'sainz',
#      'permanentNumber': '55',
#      'code': 'SAI',
#      'url': 'http://en.wikipedia.org/wiki/Carlos_Sainz_Jr.',
#      'givenName': 'Carlos',
#      'familyName': 'Sainz',
#      'dateOfBirth': '1994-09-01',
#      'nationality': 'Spanish'},
#     'Constructor': {'constructorId': 'ferrari',
#      'url': 'https://en.wikipedia.org/wiki/Scuderia_Ferrari',
#      'name': 'Ferrari',
#      'nationality': 'Italian'},
#     'grid': '2',
#     'laps': '58',
#     'status': 'Finished',
#     'Time': {'millis': '4826843', 'time': '1:20:26.843'},
#     'FastestLap': {'rank': '3',
#      'lap': '48',
#      'Time': {'time': '1:20.031'},
#      'AverageSpeed': {'units': 'kph', 'speed': '237.418'}}},
#    {'number': '16',
#     'position': '2',
#     'positionText': '2',
#     'points': '19',
#     'Driver': {'driverId': 'leclerc',
#      'permanentNumber': '16',
#      'code': 'LEC',
#      'url': 'http://en.wikipedia.org/wiki/Charles_Leclerc',
#      'givenName': 'Charles',
#      'familyName': 'Leclerc',
#      'dateOfBirth': '1997-10-16',
#      'nationality': 'Monegasque'},
#     'Constructor': {'constructorId': 'ferrari',
#      'url': 'https://en.wikipedia.org/wiki/Scuderia_Ferrari',
#      'name': 'Ferrari',
#      'nationality': 'Italian'},
#     'grid': '4',
#     'laps': '58',
#     'status': 'Finished',
#     'Time': {'millis': '4829209', 'time': '+2.366'},
#     'FastestLap': {'rank': '1',
#      'lap': '56',
#      'Time': {'time': '1:19.813'},
#      'AverageSpeed': {'units': 'kph', 'speed': '238.066'}}},
#    {'number': '4',
#     'position': '3',
#     'positionText': '3',
#     'points': '15',
#     'Driver': {'driverId': 'norris',
#      'permanentNumber': '1',
#      'code': 'NOR',
#      'url': 'http://en.wikipedia.org/wiki/Lando_Norris',
#      'givenName': 'Lando',
#      'familyName': 'Norris',
#      'dateOfBirth': '1999-11-13',
#      'nationality': 'British'},
#     'Constructor': {'constructorId': 'mclaren',
#      'url': 'https://en.wikipedia.org/wiki/McLaren',
#      'name': 'McLaren',
#      'nationality': 'British'},
#     'grid': '3',
#     'laps': '58',
#     'status': 'Finished',
#     'Time': {'millis': '4832747', 'time': '+5.904'},
#     'FastestLap': {'rank': '2', 'lap': '49', 'Time': {'time': '1:19.915'}}},
#    {'number': '81',
#     'position': '4',
#     'positionText': '4',
#     'points': '12',
#     'Driver': {'driverId': 'piastri',
#      'permanentNumber': '81',
#      'code': 'PIA',
#      'url': 'http://en.wikipedia.org/wiki/Oscar_Piastri',
#      'givenName': 'Oscar',
#      'familyName': 'Piastri',
#      'dateOfBirth': '2001-04-06',
#      'nationality': 'Australian'},
#     'Constructor': {'constructorId': 'mclaren',
#      'url': 'https://en.wikipedia.org/wiki/McLaren',
#      'name': 'McLaren',
#      'nationality': 'British'},
#     'grid': '5',
#     'laps': '58',
#     'status': 'Finished',
#     'Time': {'millis': '4862613', 'time': '+35.770'},
#     'FastestLap': {'rank': '4', 'lap': '54', 'Time': {'time': '1:20.199'}}},
#    {'number': '11',
#     'position': '5',
#     'positionText': '5',
#     'points': '10',
#     'Driver': {'driverId': 'perez',
#      'permanentNumber': '11',
#      'code': 'PER',
#      'url': 'http://en.wikipedia.org/wiki/Sergio_P%C3%A9rez',
#      'givenName': 'Sergio',
#      'familyName': 'Pérez',
#      'dateOfBirth': '1990-01-26',
#      'nationality': 'Mexican'},
#     'Constructor': {'constructorId': 'red_bull',
#      'url': 'https://en.wikipedia.org/wiki/Red_Bull_Racing',
#      'name': 'Red Bull',
#      'nationality': 'Austrian'},
#     'grid': '6',
#     'laps': '58',
#     'status': 'Finished',
#     'Time': {'millis': '4883152', 'time': '+56.309'},
#     'FastestLap': {'rank': '6',
#      'lap': '47',
#      'Time': {'time': '1:20.388'},
#      'AverageSpeed': {'units': 'kph', 'speed': '236.363'}}},
#    {'number': '18',
#     'position': '6',
#     'positionText': '6',
#     'points': '8',
#     'Driver': {'driverId': 'stroll',
#      'permanentNumber': '18',
#      'code': 'STR',
#      'url': 'http://en.wikipedia.org/wiki/Lance_Stroll',
#      'givenName': 'Lance',
#      'familyName': 'Stroll',
#      'dateOfBirth': '1998-10-29',
#      'nationality': 'Canadian'},
#     'Constructor': {'constructorId': 'aston_martin',
#      'url': 'https://en.wikipedia.org/wiki/Aston_Martin_in_Formula_One',
#      'name': 'Aston Martin',
#      'nationality': 'British'},
#     'grid': '9',
#     'laps': '58',
#     'status': 'Finished',
#     'Time': {'millis': '4920065', 'time': '+1:33.222'},
#     'FastestLap': {'rank': '8',
#      'lap': '49',
#      'Time': {'time': '1:20.930'},
#      'AverageSpeed': {'units': 'kph', 'speed': '234.780'}}},
#    {'number': '22',
#     'position': '7',
#     'positionText': '7',
#     'points': '6',
#     'Driver': {'driverId': 'tsunoda',
#      'permanentNumber': '22',
#      'code': 'TSU',
#      'url': 'http://en.wikipedia.org/wiki/Yuki_Tsunoda',
#      'givenName': 'Yuki',
#      'familyName': 'Tsunoda',
#      'dateOfBirth': '2000-05-11',
#      'nationality': 'Japanese'},
#     'Constructor': {'constructorId': 'rb',
#      'url': 'https://en.wikipedia.org/wiki/Racing_Bulls',
#      'name': 'RB F1 Team',
#      'nationality': 'Italian'},
#     'grid': '8',
#     'laps': '58',
#     'status': 'Finished',
#     'Time': {'millis': '4922444', 'time': '+1:35.601'},
#     'FastestLap': {'rank': '11',
#      'lap': '46',
#      'Time': {'time': '1:21.134'},
#      'AverageSpeed': {'units': 'kph', 'speed': '234.190'}}},
#    {'number': '14',
#     'position': '8',
#     'positionText': '8',
#     'points': '4',
#     'Driver': {'driverId': 'alonso',
#      'permanentNumber': '14',
#      'code': 'ALO',
#      'url': 'http://en.wikipedia.org/wiki/Fernando_Alonso',
#      'givenName': 'Fernando',
#      'familyName': 'Alonso',
#      'dateOfBirth': '1981-07-29',
#      'nationality': 'Spanish'},
#     'Constructor': {'constructorId': 'aston_martin',
#      'url': 'https://en.wikipedia.org/wiki/Aston_Martin_in_Formula_One',
#      'name': 'Aston Martin',
#      'nationality': 'British'},
#     'grid': '10',
#     'laps': '58',
#     'status': 'Finished',
#     'Time': {'millis': '4927835', 'time': '+1:40.992'},
#     'FastestLap': {'rank': '7',
#      'lap': '52',
#      'Time': {'time': '1:20.493'},
#      'AverageSpeed': {'units': 'kph', 'speed': '236.055'}}},
#    {'number': '27',
#     'position': '9',
#     'positionText': '9',
#     'points': '2',
#     'Driver': {'driverId': 'hulkenberg',
#      'permanentNumber': '27',
#      'code': 'HUL',
#      'url': 'http://en.wikipedia.org/wiki/Nico_H%C3%BClkenberg',
#      'givenName': 'Nico',
#      'familyName': 'Hülkenberg',
#      'dateOfBirth': '1987-08-19',
#      'nationality': 'German'},
#     'Constructor': {'constructorId': 'haas',
#      'url': 'https://en.wikipedia.org/wiki/Haas_F1_Team',
#      'name': 'Haas F1 Team',
#      'nationality': 'American'},
#     'grid': '16',
#     'laps': '58',
#     'status': 'Finished',
#     'Time': {'millis': '4931396', 'time': '+1:44.553'},
#     'FastestLap': {'rank': '12',
#      'lap': '46',
#      'Time': {'time': '1:21.145'},
#      'AverageSpeed': {'units': 'kph', 'speed': '234.158'}}},
#    {'number': '20',
#     'position': '10',
#     'positionText': '10',
#     'points': '1',
#     'Driver': {'driverId': 'kevin_magnussen',
#      'permanentNumber': '20',
#      'code': 'MAG',
#      'url': 'http://en.wikipedia.org/wiki/Kevin_Magnussen',
#      'givenName': 'Kevin',
#      'familyName': 'Magnussen',
#      'dateOfBirth': '1992-10-05',
#      'nationality': 'Danish'},
#     'Constructor': {'constructorId': 'haas',
#      'url': 'https://en.wikipedia.org/wiki/Haas_F1_Team',
#      'name': 'Haas F1 Team',
#      'nationality': 'American'},
#     'grid': '14',
#     'laps': '57',
#     'status': 'Lapped',
#     'Time': {'millis': '4830924', 'time': '+4.081'},
#     'FastestLap': {'rank': '9',
#      'lap': '44',
#      'Time': {'time': '1:21.082'},
#      'AverageSpeed': {'units': 'kph', 'speed': '234.340'}}},
#    {'number': '23',
#     'position': '11',
#     'positionText': '11',
#     'points': '0',
#     'Driver': {'driverId': 'albon',
#      'permanentNumber': '23',
#      'code': 'ALB',
#      'url': 'http://en.wikipedia.org/wiki/Alexander_Albon',
#      'givenName': 'Alexander',
#      'familyName': 'Albon',
#      'dateOfBirth': '1996-03-23',
#      'nationality': 'Thai'},
#     'Constructor': {'constructorId': 'williams',
#      'url': 'https://en.wikipedia.org/wiki/Williams_Racing',
#      'name': 'Williams',
#      'nationality': 'British'},
#     'grid': '12',
#     'laps': '57',
#     'status': 'Lapped',
#     'Time': {'millis': '4831852', 'time': '+5.009'},
#     'FastestLap': {'rank': '17',
#      'lap': '46',
#      'Time': {'time': '1:21.618'},
#      'AverageSpeed': {'units': 'kph', 'speed': '232.801'}}},
#    {'number': '3',
#     'position': '12',
#     'positionText': '12',
#     'points': '0',
#     'Driver': {'driverId': 'ricciardo',
#      'permanentNumber': '3',
#      'code': 'RIC',
#      'url': 'http://en.wikipedia.org/wiki/Daniel_Ricciardo',
#      'givenName': 'Daniel',
#      'familyName': 'Ricciardo',
#      'dateOfBirth': '1989-07-01',
#      'nationality': 'Australian'},
#     'Constructor': {'constructorId': 'rb',
#      'url': 'https://en.wikipedia.org/wiki/Racing_Bulls',
#      'name': 'RB F1 Team',
#      'nationality': 'Italian'},
#     'grid': '18',
#     'laps': '57',
#     'status': 'Lapped',
#     'Time': {'millis': '4838351', 'time': '+11.508'},
#     'FastestLap': {'rank': '13',
#      'lap': '46',
#      'Time': {'time': '1:21.239'},
#      'AverageSpeed': {'units': 'kph', 'speed': '233.887'}}},
#    {'number': '10',
#     'position': '13',
#     'positionText': '13',
#     'points': '0',
#     'Driver': {'driverId': 'gasly',
#      'permanentNumber': '10',
#      'code': 'GAS',
#      'url': 'http://en.wikipedia.org/wiki/Pierre_Gasly',
#      'givenName': 'Pierre',
#      'familyName': 'Gasly',
#      'dateOfBirth': '1996-02-07',
#      'nationality': 'French'},
#     'Constructor': {'constructorId': 'alpine',
#      'url': 'https://en.wikipedia.org/wiki/Alpine_F1_Team',
#      'name': 'Alpine F1 Team',
#      'nationality': 'French'},
#     'grid': '17',
#     'laps': '57',
#     'status': 'Lapped',
#     'Time': {'millis': '4867796', 'time': '+40.953'},
#     'FastestLap': {'rank': '10',
#      'lap': '51',
#      'Time': {'time': '1:21.090'},
#      'AverageSpeed': {'units': 'kph', 'speed': '234.317'}}},
#    {'number': '77',
#     'position': '14',
#     'positionText': '14',
#     'points': '0',
#     'Driver': {'driverId': 'bottas',
#      'permanentNumber': '77',
#      'code': 'BOT',
#      'url': 'http://en.wikipedia.org/wiki/Valtteri_Bottas',
#      'givenName': 'Valtteri',
#      'familyName': 'Bottas',
#      'dateOfBirth': '1989-08-28',
#      'nationality': 'Finnish'},
#     'Constructor': {'constructorId': 'sauber',
#      'url': 'https://en.wikipedia.org/wiki/Sauber_Motorsport',
#      'name': 'Sauber',
#      'nationality': 'Swiss'},
#     'grid': '13',
#     'laps': '57',
#     'status': 'Lapped',
#     'Time': {'millis': '4869169', 'time': '+42.326'},
#     'FastestLap': {'rank': '16',
#      'lap': '48',
#      'Time': {'time': '1:21.422'},
#      'AverageSpeed': {'units': 'kph', 'speed': '233.361'}}},
#    {'number': '24',
#     'position': '15',
#     'positionText': '15',
#     'points': '0',
#     'Driver': {'driverId': 'zhou',
#      'permanentNumber': '24',
#      'code': 'ZHO',
#      'url': 'http://en.wikipedia.org/wiki/Zhou_Guanyu',
#      'givenName': 'Guanyu',
#      'familyName': 'Zhou',
#      'dateOfBirth': '1999-05-30',
#      'nationality': 'Chinese'},
#     'Constructor': {'constructorId': 'sauber',
#      'url': 'https://en.wikipedia.org/wiki/Sauber_Motorsport',
#      'name': 'Sauber',
#      'nationality': 'Swiss'},
#     'grid': '19',
#     'laps': '57',
#     'status': 'Lapped',
#     'Time': {'millis': '4871136', 'time': '+44.293'},
#     'FastestLap': {'rank': '14',
#      'lap': '49',
#      'Time': {'time': '1:21.327'},
#      'AverageSpeed': {'units': 'kph', 'speed': '233.634'}}},
#    {'number': '31',
#     'position': '16',
#     'positionText': '16',
#     'points': '0',
#     'Driver': {'driverId': 'ocon',
#      'permanentNumber': '31',
#      'code': 'OCO',
#      'url': 'http://en.wikipedia.org/wiki/Esteban_Ocon',
#      'givenName': 'Esteban',
#      'familyName': 'Ocon',
#      'dateOfBirth': '1996-09-17',
#      'nationality': 'French'},
#     'Constructor': {'constructorId': 'alpine',
#      'url': 'https://en.wikipedia.org/wiki/Alpine_F1_Team',
#      'name': 'Alpine F1 Team',
#      'nationality': 'French'},
#     'grid': '15',
#     'laps': '57',
#     'status': 'Lapped',
#     'Time': {'millis': '4880822', 'time': '+53.979'},
#     'FastestLap': {'rank': '15',
#      'lap': '45',
#      'Time': {'time': '1:21.354'},
#      'AverageSpeed': {'units': 'kph', 'speed': '233.557'}}},
#    {'number': '63',
#     'position': '17',
#     'positionText': '17',
#     'points': '0',
#     'Driver': {'driverId': 'russell',
#      'permanentNumber': '63',
#      'code': 'RUS',
#      'url': 'http://en.wikipedia.org/wiki/George_Russell_(racing_driver)',
#      'givenName': 'George',
#      'familyName': 'Russell',
#      'dateOfBirth': '1998-02-15',
#      'nationality': 'British'},
#     'Constructor': {'constructorId': 'mercedes',
#      'url': 'https://en.wikipedia.org/wiki/Mercedes-Benz_in_Formula_One',
#      'name': 'Mercedes',
#      'nationality': 'German'},
#     'grid': '7',
#     'laps': '56',
#     'status': 'Retired',
#     'Time': {'millis': '4684734', 'time': ''},
#     'FastestLap': {'rank': '5',
#      'lap': '53',
#      'Time': {'time': '1:20.284'},
#      'AverageSpeed': {'units': 'kph', 'speed': '236.669'}}},
#    {'number': '44',
#     'position': '18',
#     'positionText': 'R',
#     'points': '0',
#     'Driver': {'driverId': 'hamilton',
#      'permanentNumber': '44',
#      'code': 'HAM',
#      'url': 'http://en.wikipedia.org/wiki/Lewis_Hamilton',
#      'givenName': 'Lewis',
#      'familyName': 'Hamilton',
#      'dateOfBirth': '1985-01-07',
#      'nationality': 'British'},
#     'Constructor': {'constructorId': 'mercedes',
#      'url': 'https://en.wikipedia.org/wiki/Mercedes-Benz_in_Formula_One',
#      'name': 'Mercedes',
#      'nationality': 'German'},
#     'grid': '11',
#     'laps': '15',
#     'status': 'Retired',
#     'FastestLap': {'rank': '18',
#      'lap': '11',
#      'Time': {'time': '1:22.444'},
#      'AverageSpeed': {'units': 'kph', 'speed': '230.469'}}},
#    {'number': '1',
#     'position': '19',
#     'positionText': 'R',
#     'points': '0',
#     'Driver': {'driverId': 'max_verstappen',
#      'permanentNumber': '3',
#      'code': 'VER',
#      'url': 'http://en.wikipedia.org/wiki/Max_Verstappen',
#      'givenName': 'Max',
#      'familyName': 'Verstappen',
#      'dateOfBirth': '1997-09-30',
#      'nationality': 'Dutch'},
#     'Constructor': {'constructorId': 'red_bull',
#      'url': 'https://en.wikipedia.org/wiki/Red_Bull_Racing',
#      'name': 'Red Bull',
#      'nationality': 'Austrian'},
#     'grid': '1',
#     'laps': '3',
#     'status': 'Retired',
#     'FastestLap': {'rank': '19',
#      'lap': '3',
#      'Time': {'time': '1:23.115'},
#      'AverageSpeed': {'units': 'kph', 'speed': '228.608'}}}]}]

# %%
BASE_URL = "https://api.jolpi.ca/ergast/f1"

# %%
import fastf1
import pandas as pd
from pathlib import Path

# ── Config ────────────────────────────────────────────────────────────────────
YEAR      = 2024
ROUND     = 1
CACHE_DIR = Path("data/cache_test")
CACHE_DIR.mkdir(parents=True, exist_ok=True)

# ── Enable cache ──────────────────────────────────────────────────────────────
fastf1.Cache.enable_cache(str(CACHE_DIR))

# ── Load session ──────────────────────────────────────────────────────────────
print(f"Loading {YEAR} Round {ROUND} race session...")
session = fastf1.get_session(YEAR, ROUND, "R")
session.load(
    laps      = True,
    telemetry = True,
    weather   = False,
    messages  = False,
)
print("Session loaded ✓")

# ── Pick one driver and one lap ───────────────────────────────────────────────
driver     = "VER"
lap_number = 5

lap      = session.laps.pick_drivers(driver).pick_laps(lap_number).iloc[0]
car_data = lap.get_car_data()

print(f"\nRaw telemetry for {driver} Lap {lap_number}:")
print(f"Shape   : {car_data.shape}")
print(f"Columns : {list(car_data.columns)}")
print(car_data.head(10))
